# %% [markdown]
# #### Step 1 - Imports

# %%
import requests
import pandas as pd
import sqlalchemy

# %% [markdown]
# #### Step 2 - Requests & CURL

# %%
import requests

headers = {
    'authority': 'api2.realtor.ca',
    'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
    'accept': '*/*',
    'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'sec-ch-ua-mobile': '?0',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
    'sec-ch-ua-platform': '"Windows"',
    'origin': 'https://www.realtor.ca',
    'sec-fetch-site': 'same-site',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.realtor.ca/',
    'accept-language': 'en-US,en;q=0.9,pt;q=0.8',
    'cookie': 'visid_incap_2269415=XY7Ff6FISH+XbDEMypW0DJXCl2EAAAAAQUIPAAAAAACa6q1MGoE55Eox1mrFFuhm; _fbp=fb.1.1637335707946.82525080; gig_bootstrap_3_mrQiIl6ov44s2X3j6NGWVZ9SDDtplqV7WgdcyEpGYnYxl7ygDWPQHqQqtpSiUfko=gigya-pr_ver4; visid_incap_2271082=BHCBF2JIQaK4CNJILm17xbLCl2EAAAAAQUIPAAAAAADFMVMUuqSR2qfEAAn3fPcA; incap_ses_1452_2269415=2aVeXzf2/zRcdEhDYYomFGuFn2EAAAAA0o392l8I4x+XO5eRXrvVxA==; nlbi_2269415=d9unboAgoRiiqWtgkG5lugAAAABDgwNL8voKdZLtsKHNnEco; _gid=GA1.2.957073111.1637844339; ASP.NET_SessionId=cop3nuc4yhokjdcz2necxjww; nlbi_2271082=4zL3PYDMEGXdaorXcbDG1QAAAABb1b+Q5x8yrL6GBBKtMhx3; incap_ses_1452_2271082=3jk1Vopiim+CekhDYYomFG+Fn2EAAAAAqAsJ92vLT413AjEkbVFJCw==; nlbi_2269415_2147483646=LhDvEZF1wxR0bEJakG5lugAAAADDYIUwi1cA4PI1DkP6uKGo; _ga=GA1.2.239090420.1637335707; reese84=3:JXnYiFIMw2zWLN0ngQVgJg==:...:EAUMrBqaOZKI74nTbJxdskhbAvyHlo5cy6fNWGWgAbg=; _4c_=fVNdb5swFP0rFVN5KtQYf0AlHrpUqiJlXbV2mrSXysAlsUowM05oWuW%2F7zqiybRK5QXf43M%2FfO%2B5b8G4gi64SkQqM8ZSIQSVF8Ez7Ibg6i2wuva%2FbXAVlFKUUjU8yhRJIiZEFZWiKaMka4AzKpNSkeAiePGxGE%2BSRBKZE7m%2FCKp%2BivEWbGyLoVbO9cPV5eU4jrEF1Tpj40pdrlX%2F5bcx6wVsoS3ycAadA1swHlNOUkrP6SySPJZ5nnMSLpTTblPDN%2FXiKZKnMgkXplse0UiymBMpshNXdwVjsWSUpf9wEY2kjElOKQ23Gsai1YMLH4x1hYhuwvtbMPN6KJYpeWooS8D94SFid2oNxXfn1KiwtnNKvt%2BF99b0YN3ucdfDrTWbfn5TJEf0AZStVv5uXiP8aFU3qMpp000YDWcba6GrdsXs%2Bgb7WZkasGVJHuex7697RQub7s%2FQ%2BcH0tsbz7fXTz%2FkNmjTNSU4YJbGfaZpynAPe99bUm8o9OcyDrBHKs6F%2BxosatrqCp1HXbuUToQRO6Ar0cuUQxi56tLeegqdRd7UZ%2F%2Fea0KOXyDmiC9UtN2oJk%2BvCLJdQn81RdUGj2gEQw%2F5sdVd5Clozs%2Bmc3aHx1apX3SL0AwZdox60ao2dmfUarK6UF5M93SCvtGYcwFc5W1mzhrPc12VQzMGvQ3EDmhYawCbbT6WIvEE7OGR4xycMt%2BMERwe495OgeGgNluW9cKuQDYfhntjBflqRVOYpapMJjuvmHL4kE4z4Dxlb%2Fb51VV5XDc%2FzKG0oj1B6MiqThkW8rlialSRtCA2OITMmcPkEo1NIlMkUsW%2BniMmJzDPJSMbFO5kd8%2FfbiU0%2FVCs%2BVlvD8OxMP73wE98PL93v%2FwI%3D; _ga_Y07J3B53QP=GS1.1.1637844338.2.1.1637844422.60; _dc_gtm_UA-12908513-11=1',
}

data = {
  'ZoomLevel': '9',
  'LatitudeMax': '45.75371',
  'LongitudeMax': '-74.50768',
  'LatitudeMin': '44.74243',
  'LongitudeMin': '-77.09222',
  'Sort': '6-D',
  'PropertyTypeGroupID': '1',
  'PropertySearchTypeId': '1',
  'TransactionTypeId': '2',
  'Currency': 'CAD',
  'RecordsPerPage': '12',
  'ApplicationId': '1',
  'CultureId': '1',
  'Version': '7.0',
  'CurrentPage': '1'
}

response = requests.post('https://api2.realtor.ca/Listing.svc/PropertySearch_Post', headers=headers, data=data)

# %% [markdown]
# #### Step 3 - Check Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# #### Step 4 - Create Json Object

# %%
response.json()
# Out:
# {'ErrorCode': {'Description': 'Success - OK',
#   'Id': 200,
#   'ProductName': '! Push to PR-Stage - Realtor API (Maintenance)^31918 [Monday, November 1, 2021 10:42:54 AM]',
#   'Status': 'Pins-Via-Cache:false;Sidebar-Items-Via-Cache:0;',
#   'Version': '1.0.7975.19296'},
#  'GroupingLevel': '6',
#  'Paging': {'CurrentPage': 1,
#   'MaxRecords': 600,
#   'Pins': 581,
#   'RecordsPerPage': 12,
#   'RecordsShowing': 600,
#   'TotalPages': 50,
#   'TotalRecords': 3216},
#  'Pins': [{'count': 1,
#    'key': 'L6|44.75|-76.2',
#    'latitude': '44.75',
#    'longitude': '-76.2',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|44.8|-76.5',
#    'latitude': '44.8',
#    'longitude': '-76.5',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|44.85|-76',
#    'latitude': '44.85',
#    'longitude': '-76',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.85|-76.9',
#    'latitude': '44.85',
#    'longitude': '-76.9',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.9|-75.6',
#    'latitude': '44.9',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.95|-75.5',
#    'latitude': '44.95',
#    'longitude': '-75.5',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.1|-74.75',
#    'latitude': '45.1',
#    'longitude': '-74.75',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.1|-75.2',
#    'latitude': '45.1',
#    'longitude': '-75.2',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.1|-76.4',
#    'latitude': '45.1',
#    'longitude': '-76.4',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.15|-76.7',
#    'latitude': '45.15',
#    'longitude': '-76.7',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.2|-75.85',
#    'latitude': '45.2',
#    'longitude': '-75.85',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.25|-76.3',
#    'latitude': '45.25',
#    'longitude': '-76.3',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.25|-76.65',
#    'latitude': '45.25',
#    'longitude': '-76.65',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.3|-75.3',
#    'latitude': '45.3',
#    'longitude': '-75.3',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|45.3|-75.55',
#    'latitude': '45.3',
#    'longitude': '-75.55',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.3|-75.65',
#    'latitude': '45.3',
#    'longitude': '-75.65',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.3|-76.25',
#    'latitude': '45.3',
#    'longitude': '-76.25',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|45.35|-75.95',
#    'latitude': '45.35',
#    'longitude': '-75.95',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.35|-76.35',
#    'latitude': '45.35',
#    'longitude': '-76.35',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.4|-75.9',
#    'latitude': '45.4',
#    'longitude': '-75.9',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.45|-76.85',
#    'latitude': '45.45',
#    'longitude': '-76.85',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.5|-76.2',
#    'latitude': '45.5',
#    'longitude': '-76.2',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.5|-76.45',
#    'latitude': '45.5',
#    'longitude': '-76.45',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.5|-77.1',
#    'latitude': '45.5',
#    'longitude': '-77.1',
#    'propertyId': ''},
#   {'count': 8,
#    'key': 'L6|45.55|-75.5',
#    'latitude': '45.55',
#    'longitude': '-75.5',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.6|-76.85',
#    'latitude': '45.6',
#    'longitude': '-76.85',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.65|-74.6',
#    'latitude': '45.65',
#    'longitude': '-74.6',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.65|-75',
#    'latitude': '45.65',
#    'longitude': '-75',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|45.65|-75.75',
#    'latitude': '45.65',
#    'longitude': '-75.75',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.65|-77',
#    'latitude': '45.65',
#    'longitude': '-77',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.7|-76.15',
#    'latitude': '45.7',
#    'longitude': '-76.15',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.7|-76.8',
#    'latitude': '45.7',
#    'longitude': '-76.8',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45|-75.35',
#    'latitude': '45',
#    'longitude': '-75.35',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45|-75.8',
#    'latitude': '45',
#    'longitude': '-75.8',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.8|-75.65',
#    'latitude': '44.8',
#    'longitude': '-75.65',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|44.85|-75.9',
#    'latitude': '44.85',
#    'longitude': '-75.9',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.9|-75.4',
#    'latitude': '44.9',
#    'longitude': '-75.4',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.9|-76.6',
#    'latitude': '44.9',
#    'longitude': '-76.6',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.1|-74.55',
#    'latitude': '45.1',
#    'longitude': '-74.55',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.1|-74.6',
#    'latitude': '45.1',
#    'longitude': '-74.6',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.15|-74.85',
#    'latitude': '45.15',
#    'longitude': '-74.85',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.15|-75.45',
#    'latitude': '45.15',
#    'longitude': '-75.45',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.15|-75.6',
#    'latitude': '45.15',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.2|-76.15',
#    'latitude': '45.2',
#    'longitude': '-76.15',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.25|-75.6',
#    'latitude': '45.25',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.3|-76.45',
#    'latitude': '45.3',
#    'longitude': '-76.45',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.3|-76.7',
#    'latitude': '45.3',
#    'longitude': '-76.7',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.35|-75.3',
#    'latitude': '45.35',
#    'longitude': '-75.3',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.35|-76.65',
#    'latitude': '45.35',
#    'longitude': '-76.65',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.4|-76.1',
#    'latitude': '45.4',
#    'longitude': '-76.1',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.4|-76.3',
#    'latitude': '45.4',
#    'longitude': '-76.3',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.4|-76.35',
#    'latitude': '45.4',
#    'longitude': '-76.35',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.4|-77.05',
#    'latitude': '45.4',
#    'longitude': '-77.05',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.45|-75.05',
#    'latitude': '45.45',
#    'longitude': '-75.05',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.45|-75.9',
#    'latitude': '45.45',
#    'longitude': '-75.9',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.45|-75.95',
#    'latitude': '45.45',
#    'longitude': '-75.95',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.45|-76.1',
#    'latitude': '45.45',
#    'longitude': '-76.1',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.5|-74.7',
#    'latitude': '45.5',
#    'longitude': '-74.7',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.5|-74.9',
#    'latitude': '45.5',
#    'longitude': '-74.9',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.5|-76.35',
#    'latitude': '45.5',
#    'longitude': '-76.35',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.55|-74.8',
#    'latitude': '45.55',
#    'longitude': '-74.8',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.55|-75.15',
#    'latitude': '45.55',
#    'longitude': '-75.15',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.6|-74.55',
#    'latitude': '45.6',
#    'longitude': '-74.55',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.65|-75.25',
#    'latitude': '45.65',
#    'longitude': '-75.25',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.65|-75.55',
#    'latitude': '45.65',
#    'longitude': '-75.55',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|45.7|-74.75',
#    'latitude': '45.7',
#    'longitude': '-74.75',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|45.7|-75.75',
#    'latitude': '45.7',
#    'longitude': '-75.75',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.7|-76.65',
#    'latitude': '45.7',
#    'longitude': '-76.65',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.75|-76.95',
#    'latitude': '45.75',
#    'longitude': '-76.95',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45|-76.45',
#    'latitude': '45',
#    'longitude': '-76.45',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45|-76.5',
#    'latitude': '45',
#    'longitude': '-76.5',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.75|-75.55',
#    'latitude': '44.75',
#    'longitude': '-75.55',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.75|-76.4',
#    'latitude': '44.75',
#    'longitude': '-76.4',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|44.8|-76.1',
#    'latitude': '44.8',
#    'longitude': '-76.1',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.85|-75.7',
#    'latitude': '44.85',
#    'longitude': '-75.7',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.85|-76.5',
#    'latitude': '44.85',
#    'longitude': '-76.5',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|44.9|-75.2',
#    'latitude': '44.9',
#    'longitude': '-75.2',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.95|-75.25',
#    'latitude': '44.95',
#    'longitude': '-75.25',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.05|-75.4',
#    'latitude': '45.05',
#    'longitude': '-75.4',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.05|-75.95',
#    'latitude': '45.05',
#    'longitude': '-75.95',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.05|-76.65',
#    'latitude': '45.05',
#    'longitude': '-76.65',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.1|-75.25',
#    'latitude': '45.1',
#    'longitude': '-75.25',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.2|-75.55',
#    'latitude': '45.2',
#    'longitude': '-75.55',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.2|-76.25',
#    'latitude': '45.2',
#    'longitude': '-76.25',
#    'propertyId': ''},
#   {'count': 22,
#    'key': 'L6|45.25|-75.9',
#    'latitude': '45.25',
#    'longitude': '-75.9',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.25|-77.1',
#    'latitude': '45.25',
#    'longitude': '-77.1',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.3|-74.65',
#    'latitude': '45.3',
#    'longitude': '-74.65',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.3|-76.65',
#    'latitude': '45.3',
#    'longitude': '-76.65',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.35|-75.05',
#    'latitude': '45.35',
#    'longitude': '-75.05',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.35|-75.1',
#    'latitude': '45.35',
#    'longitude': '-75.1',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.35|-76.15',
#    'latitude': '45.35',
#    'longitude': '-76.15',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.35|-76.9',
#    'latitude': '45.35',
#    'longitude': '-76.9',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.4|-76.85',
#    'latitude': '45.4',
#    'longitude': '-76.85',
#    'propertyId': ''},
#   {'count': 25,
#    'key': 'L6|45.45|-76.35',
#    'latitude': '45.45',
#    'longitude': '-76.35',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.45|-76.45',
#    'latitude': '45.45',
#    'longitude': '-76.45',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.5|-74.65',
#    'latitude': '45.5',
#    'longitude': '-74.65',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.5|-75.3',
#    'latitude': '45.5',
#    'longitude': '-75.3',
#    'propertyId': ''},
#   {'count': 18,
#    'key': 'L6|45.5|-75.55',
#    'latitude': '45.5',
#    'longitude': '-75.55',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.5|-76.6',
#    'latitude': '45.5',
#    'longitude': '-76.6',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.5|-77',
#    'latitude': '45.5',
#    'longitude': '-77',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|45.55|-75.1',
#    'latitude': '45.55',
#    'longitude': '-75.1',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.55|-76.75',
#    'latitude': '45.55',
#    'longitude': '-76.75',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.7|-75.1',
#    'latitude': '45.7',
#    'longitude': '-75.1',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.7|-75.65',
#    'latitude': '45.7',
#    'longitude': '-75.65',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.7|-76',
#    'latitude': '45.7',
#    'longitude': '-76',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.75|-75.9',
#    'latitude': '45.75',
#    'longitude': '-75.9',
#    'propertyId': ''},
#   {'count': 11,
#    'key': 'L6|45|-74.7',
#    'latitude': '45',
#    'longitude': '-74.7',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45|-75.4',
#    'latitude': '45',
#    'longitude': '-75.4',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45|-75.45',
#    'latitude': '45',
#    'longitude': '-75.45',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45|-76.3',
#    'latitude': '45',
#    'longitude': '-76.3',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.8|-75.45',
#    'latitude': '44.8',
#    'longitude': '-75.45',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|44.8|-75.95',
#    'latitude': '44.8',
#    'longitude': '-75.95',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.8|-76.75',
#    'latitude': '44.8',
#    'longitude': '-76.75',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.9|-75.75',
#    'latitude': '44.9',
#    'longitude': '-75.75',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.95|-75.2',
#    'latitude': '44.95',
#    'longitude': '-75.2',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|44.95|-75.95',
#    'latitude': '44.95',
#    'longitude': '-75.95',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|44.95|-76.1',
#    'latitude': '44.95',
#    'longitude': '-76.1',
#    'propertyId': ''},
#   {'count': 15,
#    'key': 'L6|45.05|-74.75',
#    'latitude': '45.05',
#    'longitude': '-74.75',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.05|-75.3',
#    'latitude': '45.05',
#    'longitude': '-75.3',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.05|-76.7',
#    'latitude': '45.05',
#    'longitude': '-76.7',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.1|-74.85',
#    'latitude': '45.1',
#    'longitude': '-74.85',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.1|-77.1',
#    'latitude': '45.1',
#    'longitude': '-77.1',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.15|-76.05',
#    'latitude': '45.15',
#    'longitude': '-76.05',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.15|-76.6',
#    'latitude': '45.15',
#    'longitude': '-76.6',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.25|-75.8',
#    'latitude': '45.25',
#    'longitude': '-75.8',
#    'propertyId': ''},
#   {'count': 8,
#    'key': 'L6|45.3|-76',
#    'latitude': '45.3',
#    'longitude': '-76',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.3|-76.2',
#    'latitude': '45.3',
#    'longitude': '-76.2',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.5|-76.7',
#    'latitude': '45.5',
#    'longitude': '-76.7',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.6|-75.85',
#    'latitude': '45.6',
#    'longitude': '-75.85',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.65|-74.9',
#    'latitude': '45.65',
#    'longitude': '-74.9',
#    'propertyId': ''},
#   {'count': 8,
#    'key': 'L6|45.65|-75.35',
#    'latitude': '45.65',
#    'longitude': '-75.35',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.65|-75.45',
#    'latitude': '45.65',
#    'longitude': '-75.45',
#    'propertyId': ''},
#   {'count': 8,
#    'key': 'L6|45.65|-75.65',
#    'latitude': '45.65',
#    'longitude': '-75.65',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.75|-76',
#    'latitude': '45.75',
#    'longitude': '-76',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.75|-76.8',
#    'latitude': '45.75',
#    'longitude': '-76.8',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45|-75.5',
#    'latitude': '45',
#    'longitude': '-75.5',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45|-76.4',
#    'latitude': '45',
#    'longitude': '-76.4',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45|-76.65',
#    'latitude': '45',
#    'longitude': '-76.65',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.75|-75.6',
#    'latitude': '44.75',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|44.8|-76.9',
#    'latitude': '44.8',
#    'longitude': '-76.9',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.85|-75.35',
#    'latitude': '44.85',
#    'longitude': '-75.35',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.95|-75.1',
#    'latitude': '44.95',
#    'longitude': '-75.1',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.05|-76.05',
#    'latitude': '45.05',
#    'longitude': '-76.05',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.1|-76.25',
#    'latitude': '45.1',
#    'longitude': '-76.25',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.15|-76.3',
#    'latitude': '45.15',
#    'longitude': '-76.3',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.2|-76.2',
#    'latitude': '45.2',
#    'longitude': '-76.2',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.25|-76.55',
#    'latitude': '45.25',
#    'longitude': '-76.55',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.25|-76.7',
#    'latitude': '45.25',
#    'longitude': '-76.7',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.3|-74.75',
#    'latitude': '45.3',
#    'longitude': '-74.75',
#    'propertyId': ''},
#   {'count': 15,
#    'key': 'L6|45.3|-75.7',
#    'latitude': '45.3',
#    'longitude': '-75.7',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.3|-76.05',
#    'latitude': '45.3',
#    'longitude': '-76.05',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.35|-74.9',
#    'latitude': '45.35',
#    'longitude': '-74.9',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.4|-75.45',
#    'latitude': '45.4',
#    'longitude': '-75.45',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.4|-76.25',
#    'latitude': '45.4',
#    'longitude': '-76.25',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.5|-75',
#    'latitude': '45.5',
#    'longitude': '-75',
#    'propertyId': ''},
#   {'count': 16,
#    'key': 'L6|45.5|-75.5',
#    'latitude': '45.5',
#    'longitude': '-75.5',
#    'propertyId': ''},
#   {'count': 15,
#    'key': 'L6|45.5|-75.8',
#    'latitude': '45.5',
#    'longitude': '-75.8',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.55|-75.55',
#    'latitude': '45.55',
#    'longitude': '-75.55',
#    'propertyId': ''},
#   {'count': 13,
#    'key': 'L6|45.55|-75.8',
#    'latitude': '45.55',
#    'longitude': '-75.8',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.55|-77.05',
#    'latitude': '45.55',
#    'longitude': '-77.05',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.6|-74.7',
#    'latitude': '45.6',
#    'longitude': '-74.7',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.6|-75.35',
#    'latitude': '45.6',
#    'longitude': '-75.35',
#    'propertyId': ''},
#   {'count': 16,
#    'key': 'L6|45.65|-75.6',
#    'latitude': '45.65',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 14,
#    'key': 'L6|45.65|-75.9',
#    'latitude': '45.65',
#    'longitude': '-75.9',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.7|-76.3',
#    'latitude': '45.7',
#    'longitude': '-76.3',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.75|-75.6',
#    'latitude': '45.75',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45|-75',
#    'latitude': '45',
#    'longitude': '-75',
#    'propertyId': ''},
#   {'count': 13,
#    'key': 'L6|45|-75.65',
#    'latitude': '45',
#    'longitude': '-75.65',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45|-75.75',
#    'latitude': '45',
#    'longitude': '-75.75',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45|-76',
#    'latitude': '45',
#    'longitude': '-76',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|44.75|-76.9',
#    'latitude': '44.75',
#    'longitude': '-76.9',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.85|-75.75',
#    'latitude': '44.85',
#    'longitude': '-75.75',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|44.85|-75.8',
#    'latitude': '44.85',
#    'longitude': '-75.8',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|44.95|-76.15',
#    'latitude': '44.95',
#    'longitude': '-76.15',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.95|-76.55',
#    'latitude': '44.95',
#    'longitude': '-76.55',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.95|-76.65',
#    'latitude': '44.95',
#    'longitude': '-76.65',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.05|-74.65',
#    'latitude': '45.05',
#    'longitude': '-74.65',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.05|-75.5',
#    'latitude': '45.05',
#    'longitude': '-75.5',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.1|-75.15',
#    'latitude': '45.1',
#    'longitude': '-75.15',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.1|-75.65',
#    'latitude': '45.1',
#    'longitude': '-75.65',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.1|-76.05',
#    'latitude': '45.1',
#    'longitude': '-76.05',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.15|-75.95',
#    'latitude': '45.15',
#    'longitude': '-75.95',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.2|-74.6',
#    'latitude': '45.2',
#    'longitude': '-74.6',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.2|-75.6',
#    'latitude': '45.2',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.2|-75.9',
#    'latitude': '45.2',
#    'longitude': '-75.9',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.25|-74.7',
#    'latitude': '45.25',
#    'longitude': '-74.7',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.25|-75.45',
#    'latitude': '45.25',
#    'longitude': '-75.45',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.25|-75.5',
#    'latitude': '45.25',
#    'longitude': '-75.5',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.3|-74.95',
#    'latitude': '45.3',
#    'longitude': '-74.95',
#    'propertyId': ''},
#   {'count': 14,
#    'key': 'L6|45.3|-75.75',
#    'latitude': '45.3',
#    'longitude': '-75.75',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.3|-76.8',
#    'latitude': '45.3',
#    'longitude': '-76.8',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.35|-75.85',
#    'latitude': '45.35',
#    'longitude': '-75.85',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.35|-76.05',
#    'latitude': '45.35',
#    'longitude': '-76.05',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.4|-76.15',
#    'latitude': '45.4',
#    'longitude': '-76.15',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.4|-76.65',
#    'latitude': '45.4',
#    'longitude': '-76.65',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.45|-74.95',
#    'latitude': '45.45',
#    'longitude': '-74.95',
#    'propertyId': ''},
#   {'count': 10,
#    'key': 'L6|45.45|-75.45',
#    'latitude': '45.45',
#    'longitude': '-75.45',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|45.45|-76',
#    'latitude': '45.45',
#    'longitude': '-76',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.45|-76.2',
#    'latitude': '45.45',
#    'longitude': '-76.2',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.45|-76.25',
#    'latitude': '45.45',
#    'longitude': '-76.25',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.5|-75.2',
#    'latitude': '45.5',
#    'longitude': '-75.2',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.55|-75.2',
#    'latitude': '45.55',
#    'longitude': '-75.2',
#    'propertyId': ''},
#   {'count': 9,
#    'key': 'L6|45.55|-75.45',
#    'latitude': '45.55',
#    'longitude': '-75.45',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.6|-75.8',
#    'latitude': '45.6',
#    'longitude': '-75.8',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.65|-74.85',
#    'latitude': '45.65',
#    'longitude': '-74.85',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.65|-75.2',
#    'latitude': '45.65',
#    'longitude': '-75.2',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.65|-76.65',
#    'latitude': '45.65',
#    'longitude': '-76.65',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.7|-75.6',
#    'latitude': '45.7',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.75|-75.75',
#    'latitude': '45.75',
#    'longitude': '-75.75',
#    'propertyId': ''},
#   {'count': 9,
#    'key': 'L6|45|-76.35',
#    'latitude': '45',
#    'longitude': '-76.35',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|44.75|-75.45',
#    'latitude': '44.75',
#    'longitude': '-75.45',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.75|-75.8',
#    'latitude': '44.75',
#    'longitude': '-75.8',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.85|-76.15',
#    'latitude': '44.85',
#    'longitude': '-76.15',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.9|-76.3',
#    'latitude': '44.9',
#    'longitude': '-76.3',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.9|-77.05',
#    'latitude': '44.9',
#    'longitude': '-77.05',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|44.95|-76.25',
#    'latitude': '44.95',
#    'longitude': '-76.25',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.95|-76.3',
#    'latitude': '44.95',
#    'longitude': '-76.3',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.05|-74.7',
#    'latitude': '45.05',
#    'longitude': '-74.7',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.05|-75.7',
#    'latitude': '45.05',
#    'longitude': '-75.7',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.05|-76.3',
#    'latitude': '45.05',
#    'longitude': '-76.3',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|45.1|-74.8',
#    'latitude': '45.1',
#    'longitude': '-74.8',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.1|-76.1',
#    'latitude': '45.1',
#    'longitude': '-76.1',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.15|-75.05',
#    'latitude': '45.15',
#    'longitude': '-75.05',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.15|-75.3',
#    'latitude': '45.15',
#    'longitude': '-75.3',
#    'propertyId': ''},
#   {'count': 42,
#    'key': 'L6|45.15|-76.1',
#    'latitude': '45.15',
#    'longitude': '-76.1',
#    'propertyId': ''},
#   {'count': 9,
#    'key': 'L6|45.2|-75.15',
#    'latitude': '45.2',
#    'longitude': '-75.15',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.3|-75.8',
#    'latitude': '45.3',
#    'longitude': '-75.8',
#    'propertyId': ''},
#   {'count': 11,
#    'key': 'L6|45.3|-75.85',
#    'latitude': '45.3',
#    'longitude': '-75.85',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.3|-76.75',
#    'latitude': '45.3',
#    'longitude': '-76.75',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.35|-76.5',
#    'latitude': '45.35',
#    'longitude': '-76.5',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.4|-75.2',
#    'latitude': '45.4',
#    'longitude': '-75.2',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.45|-75.25',
#    'latitude': '45.45',
#    'longitude': '-75.25',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.45|-76.55',
#    'latitude': '45.45',
#    'longitude': '-76.55',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.45|-76.8',
#    'latitude': '45.45',
#    'longitude': '-76.8',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.5|-76.95',
#    'latitude': '45.5',
#    'longitude': '-76.95',
#    'propertyId': ''},
#   {'count': 16,
#    'key': 'L6|45.55|-75.75',
#    'latitude': '45.55',
#    'longitude': '-75.75',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.55|-76.15',
#    'latitude': '45.55',
#    'longitude': '-76.15',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.6|-75.5',
#    'latitude': '45.6',
#    'longitude': '-75.5',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.65|-74.55',
#    'latitude': '45.65',
#    'longitude': '-74.55',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.65|-75.4',
#    'latitude': '45.65',
#    'longitude': '-75.4',
#    'propertyId': ''},
#   {'count': 21,
#    'key': 'L6|45.65|-75.7',
#    'latitude': '45.65',
#    'longitude': '-75.7',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.65|-75.95',
#    'latitude': '45.65',
#    'longitude': '-75.95',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.65|-76.3',
#    'latitude': '45.65',
#    'longitude': '-76.3',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.65|-76.6',
#    'latitude': '45.65',
#    'longitude': '-76.6',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.65|-76.9',
#    'latitude': '45.65',
#    'longitude': '-76.9',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.7|-76.1',
#    'latitude': '45.7',
#    'longitude': '-76.1',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45|-74.95',
#    'latitude': '45',
#    'longitude': '-74.95',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45|-75.05',
#    'latitude': '45',
#    'longitude': '-75.05',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.75|-76.05',
#    'latitude': '44.75',
#    'longitude': '-76.05',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.8|-76.2',
#    'latitude': '44.8',
#    'longitude': '-76.2',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|44.85|-75.25',
#    'latitude': '44.85',
#    'longitude': '-75.25',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.85|-76.25',
#    'latitude': '44.85',
#    'longitude': '-76.25',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.85|-76.4',
#    'latitude': '44.85',
#    'longitude': '-76.4',
#    'propertyId': ''},
#   {'count': 14,
#    'key': 'L6|44.9|-76',
#    'latitude': '44.9',
#    'longitude': '-76',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.9|-76.15',
#    'latitude': '44.9',
#    'longitude': '-76.15',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.95|-75.8',
#    'latitude': '44.95',
#    'longitude': '-75.8',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.05|-75.1',
#    'latitude': '45.05',
#    'longitude': '-75.1',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.05|-76.45',
#    'latitude': '45.05',
#    'longitude': '-76.45',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.1|-74.5',
#    'latitude': '45.1',
#    'longitude': '-74.5',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.1|-75.1',
#    'latitude': '45.1',
#    'longitude': '-75.1',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.1|-76.35',
#    'latitude': '45.1',
#    'longitude': '-76.35',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.15|-76',
#    'latitude': '45.15',
#    'longitude': '-76',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.15|-76.85',
#    'latitude': '45.15',
#    'longitude': '-76.85',
#    'propertyId': ''},
#   {'count': 10,
#    'key': 'L6|45.25|-75.85',
#    'latitude': '45.25',
#    'longitude': '-75.85',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.3|-77.05',
#    'latitude': '45.3',
#    'longitude': '-77.05',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.35|-74.7',
#    'latitude': '45.35',
#    'longitude': '-74.7',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.4|-74.9',
#    'latitude': '45.4',
#    'longitude': '-74.9',
#    'propertyId': ''},
#   {'count': 58,
#    'key': 'L6|45.4|-75.8',
#    'latitude': '45.4',
#    'longitude': '-75.8',
#    'propertyId': ''},
#   {'count': 43,
#    'key': 'L6|45.4|-75.85',
#    'latitude': '45.4',
#    'longitude': '-75.85',
#    'propertyId': ''},
#   {'count': 24,
#    'key': 'L6|45.5|-75.75',
#    'latitude': '45.5',
#    'longitude': '-75.75',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.5|-76.1',
#    'latitude': '45.5',
#    'longitude': '-76.1',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.5|-76.5',
#    'latitude': '45.5',
#    'longitude': '-76.5',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.55|-74.9',
#    'latitude': '45.55',
#    'longitude': '-74.9',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.55|-75.6',
#    'latitude': '45.55',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.55|-75.65',
#    'latitude': '45.55',
#    'longitude': '-75.65',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.65|-76.85',
#    'latitude': '45.65',
#    'longitude': '-76.85',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.7|-74.55',
#    'latitude': '45.7',
#    'longitude': '-74.55',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.7|-75.45',
#    'latitude': '45.7',
#    'longitude': '-75.45',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.75|-76.15',
#    'latitude': '44.75',
#    'longitude': '-76.15',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.8|-76.7',
#    'latitude': '44.8',
#    'longitude': '-76.7',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.8|-77.05',
#    'latitude': '44.8',
#    'longitude': '-77.05',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.95|-75.55',
#    'latitude': '44.95',
#    'longitude': '-75.55',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|44.95|-76.45',
#    'latitude': '44.95',
#    'longitude': '-76.45',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.1|-75.8',
#    'latitude': '45.1',
#    'longitude': '-75.8',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.1|-76.15',
#    'latitude': '45.1',
#    'longitude': '-76.15',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.15|-76.4',
#    'latitude': '45.15',
#    'longitude': '-76.4',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.2|-74.9',
#    'latitude': '45.2',
#    'longitude': '-74.9',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.2|-76.1',
#    'latitude': '45.2',
#    'longitude': '-76.1',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.25|-75.1',
#    'latitude': '45.25',
#    'longitude': '-75.1',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.25|-76.6',
#    'latitude': '45.25',
#    'longitude': '-76.6',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.3|-75.5',
#    'latitude': '45.3',
#    'longitude': '-75.5',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.35|-75.15',
#    'latitude': '45.35',
#    'longitude': '-75.15',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|45.35|-75.35',
#    'latitude': '45.35',
#    'longitude': '-75.35',
#    'propertyId': ''},
#   {'count': 9,
#    'key': 'L6|45.35|-75.6',
#    'latitude': '45.35',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 43,
#    'key': 'L6|45.35|-75.8',
#    'latitude': '45.35',
#    'longitude': '-75.8',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.35|-76.2',
#    'latitude': '45.35',
#    'longitude': '-76.2',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.4|-75.5',
#    'latitude': '45.4',
#    'longitude': '-75.5',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.4|-76.8',
#    'latitude': '45.4',
#    'longitude': '-76.8',
#    'propertyId': ''},
#   {'count': 29,
#    'key': 'L6|45.45|-75.6',
#    'latitude': '45.45',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 11,
#    'key': 'L6|45.45|-75.85',
#    'latitude': '45.45',
#    'longitude': '-75.85',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.5|-75.15',
#    'latitude': '45.5',
#    'longitude': '-75.15',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.5|-75.35',
#    'latitude': '45.5',
#    'longitude': '-75.35',
#    'propertyId': ''},
#   {'count': 52,
#    'key': 'L6|45.5|-75.6',
#    'latitude': '45.5',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.5|-76.15',
#    'latitude': '45.5',
#    'longitude': '-76.15',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.55|-75.7',
#    'latitude': '45.55',
#    'longitude': '-75.7',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.6|-74.5',
#    'latitude': '45.6',
#    'longitude': '-74.5',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.6|-75.6',
#    'latitude': '45.6',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 9,
#    'key': 'L6|45.7|-75.05',
#    'latitude': '45.7',
#    'longitude': '-75.05',
#    'propertyId': ''},
#   {'count': 9,
#    'key': 'L6|45.75|-76.6',
#    'latitude': '45.75',
#    'longitude': '-76.6',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.75|-76.7',
#    'latitude': '44.75',
#    'longitude': '-76.7',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|44.85|-75.55',
#    'latitude': '44.85',
#    'longitude': '-75.55',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.85|-76.2',
#    'latitude': '44.85',
#    'longitude': '-76.2',
#    'propertyId': ''},
#   {'count': 13,
#    'key': 'L6|44.9|-76.05',
#    'latitude': '44.9',
#    'longitude': '-76.05',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|44.9|-76.85',
#    'latitude': '44.9',
#    'longitude': '-76.85',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|44.9|-76.9',
#    'latitude': '44.9',
#    'longitude': '-76.9',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.1|-76',
#    'latitude': '45.1',
#    'longitude': '-76',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.15|-74.6',
#    'latitude': '45.15',
#    'longitude': '-74.6',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.2|-75.4',
#    'latitude': '45.2',
#    'longitude': '-75.4',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.2|-76.6',
#    'latitude': '45.2',
#    'longitude': '-76.6',
#    'propertyId': ''},
#   {'count': 10,
#    'key': 'L6|45.25|-75.55',
#    'latitude': '45.25',
#    'longitude': '-75.55',
#    'propertyId': ''},
#   {'count': 13,
#    'key': 'L6|45.25|-75.7',
#    'latitude': '45.25',
#    'longitude': '-75.7',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.25|-76.25',
#    'latitude': '45.25',
#    'longitude': '-76.25',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.3|-74.6',
#    'latitude': '45.3',
#    'longitude': '-74.6',
#    'propertyId': ''},
#   {'count': 8,
#    'key': 'L6|45.35|-75.45',
#    'latitude': '45.35',
#    'longitude': '-75.45',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.35|-76',
#    'latitude': '45.35',
#    'longitude': '-76',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.35|-76.8',
#    'latitude': '45.35',
#    'longitude': '-76.8',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.4|-75.05',
#    'latitude': '45.4',
#    'longitude': '-75.05',
#    'propertyId': ''},
#   {'count': 101,
#    'key': 'L6|45.4|-75.75',
#    'latitude': '45.4',
#    'longitude': '-75.75',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.4|-76',
#    'latitude': '45.4',
#    'longitude': '-76',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.4|-76.55',
#    'latitude': '45.4',
#    'longitude': '-76.55',
#    'propertyId': ''},
#   {'count': 16,
#    'key': 'L6|45.45|-75.55',
#    'latitude': '45.45',
#    'longitude': '-75.55',
#    'propertyId': ''},
#   {'count': 24,
#    'key': 'L6|45.45|-75.8',
#    'latitude': '45.45',
#    'longitude': '-75.8',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.5|-75.4',
#    'latitude': '45.5',
#    'longitude': '-75.4',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|45.5|-76.25',
#    'latitude': '45.5',
#    'longitude': '-76.25',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.5|-77.05',
#    'latitude': '45.5',
#    'longitude': '-77.05',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.55|-75.35',
#    'latitude': '45.55',
#    'longitude': '-75.35',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.55|-76.2',
#    'latitude': '45.55',
#    'longitude': '-76.2',
#    'propertyId': ''},
#   {'count': 10,
#    'key': 'L6|45.6|-75.65',
#    'latitude': '45.6',
#    'longitude': '-75.65',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.6|-75.95',
#    'latitude': '45.6',
#    'longitude': '-75.95',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.75|-74.7',
#    'latitude': '45.75',
#    'longitude': '-74.7',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.75|-75.05',
#    'latitude': '45.75',
#    'longitude': '-75.05',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45|-76.75',
#    'latitude': '45',
#    'longitude': '-76.75',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.75|-76.55',
#    'latitude': '44.75',
#    'longitude': '-76.55',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.85|-75.95',
#    'latitude': '44.85',
#    'longitude': '-75.95',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.85|-76.3',
#    'latitude': '44.85',
#    'longitude': '-76.3',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|44.85|-76.35',
#    'latitude': '44.85',
#    'longitude': '-76.35',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.95|-75.7',
#    'latitude': '44.95',
#    'longitude': '-75.7',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|45.05|-75.6',
#    'latitude': '45.05',
#    'longitude': '-75.6',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.15|-74.7',
#    'latitude': '45.15',
#    'longitude': '-74.7',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.15|-75.85',
#    'latitude': '45.15',
#    'longitude': '-75.85',
#    'propertyId': ''},
#   {'count': 7,
#    'key': 'L6|45.15|-75.9',
#    'latitude': '45.15',
#    'longitude': '-75.9',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.15|-76.2',
#    'latitude': '45.15',
#    'longitude': '-76.2',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.2|-74.85',
#    'latitude': '45.2',
#    'longitude': '-74.85',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.2|-75.75',
#    'latitude': '45.2',
#    'longitude': '-75.75',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.2|-76.7',
#    'latitude': '45.2',
#    'longitude': '-76.7',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.25|-74.65',
#    'latitude': '45.25',
#    'longitude': '-74.65',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.25|-74.9',
#    'latitude': '45.25',
#    'longitude': '-74.9',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.25|-74.95',
#    'latitude': '45.25',
#    'longitude': '-74.95',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.25|-75.95',
#    'latitude': '45.25',
#    'longitude': '-75.95',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.35|-74.75',
#    'latitude': '45.35',
#    'longitude': '-74.75',
#    'propertyId': ''},
#   {'count': 70,
#    'key': 'L6|45.45|-75.65',
#    'latitude': '45.45',
#    'longitude': '-75.65',
#    'propertyId': ''},
#   {'count': 58,
#    'key': 'L6|45.45|-75.75',
#    'latitude': '45.45',
#    'longitude': '-75.75',
#    'propertyId': ''},
#   {'count': 8,
#    'key': 'L6|45.45|-76.65',
#    'latitude': '45.45',
#    'longitude': '-76.65',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.45|-76.75',
#    'latitude': '45.45',
#    'longitude': '-76.75',
#    'propertyId': ''},
#   {'count': 57,
#    'key': 'L6|45.5|-75.65',
#    'latitude': '45.5',
#    'longitude': '-75.65',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.6|-74.65',
#    'latitude': '45.6',
#    'longitude': '-74.65',
#    'propertyId': ''},
#   {'count': 8,
#    'key': 'L6|45.6|-75.05',
#    'latitude': '45.6',
#    'longitude': '-75.05',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|45.6|-75.55',
#    'latitude': '45.6',
#    'longitude': '-75.55',
#    'propertyId': ''},
#   {'count': 6,
#    'key': 'L6|45.6|-75.9',
#    'latitude': '45.6',
#    'longitude': '-75.9',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.6|-77.1',
#    'latitude': '45.6',
#    'longitude': '-77.1',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.65|-76.1',
#    'latitude': '45.65',
#    'longitude': '-76.1',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.7|-75.5',
#    'latitude': '45.7',
#    'longitude': '-75.5',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.7|-75.95',
#    'latitude': '45.7',
#    'longitude': '-75.95',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.75|-75.7',
#    'latitude': '45.75',
#    'longitude': '-75.7',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45|-75.7',
#    'latitude': '45',
#    'longitude': '-75.7',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45|-76.05',
#    'latitude': '45',
#    'longitude': '-76.05',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45|-77.1',
#    'latitude': '45',
#    'longitude': '-77.1',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.85|-76.8',
#    'latitude': '44.85',
#    'longitude': '-76.8',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.05|-74.95',
#    'latitude': '45.05',
#    'longitude': '-74.95',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.05|-75.75',
#    'latitude': '45.05',
#    'longitude': '-75.75',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.1|-75',
#    'latitude': '45.1',
#    'longitude': '-75',
#    'propertyId': ''},
#   {'count': 8,
#    'key': 'L6|45.1|-75.35',
#    'latitude': '45.1',
#    'longitude': '-75.35',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.15|-74.5',
#    'latitude': '45.15',
#    'longitude': '-74.5',
#    'propertyId': ''},
#   {'count': 10,
#    'key': 'L6|45.15|-76.15',
#    'latitude': '45.15',
#    'longitude': '-76.15',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.15|-76.55',
#    'latitude': '45.15',
#    'longitude': '-76.55',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.2|-75.25',
#    'latitude': '45.2',
#    'longitude': '-75.25',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.2|-76.5',
#    'latitude': '45.2',
#    'longitude': '-76.5',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.25|-74.75',
#    'latitude': '45.25',
#    'longitude': '-74.75',
#    'propertyId': ''},
#   {'count': 20,
#    'key': 'L6|45.25|-76.2',
#    'latitude': '45.25',
#    'longitude': '-76.2',
#    'propertyId': ''},
#   {'count': 26,
#    'key': 'L6|45.3|-75.9',
#    'latitude': '45.3',
#    'longitude': '-75.9',
#    'propertyId': ''},
#   {'count': 8,
#    'key': 'L6|45.3|-75.95',
#    'latitude': '45.3',
#    'longitude': '-75.95',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.35|-76.75',
#    'latitude': '45.35',
#    'longitude': '-76.75',
#    'propertyId': ''},
#   {'count': 17,
#    'key': 'L6|45.4|-76.4',
#    'latitude': '45.4',
#    'longitude': '-76.4',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.45|-74.9',
#    'latitude': '45.45',
#    'longitude': '-74.9',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.45|-75.15',
#    'latitude': '45.45',
#    'longitude': '-75.15',
#    'propertyId': ''},
#   {'count': 48,
#    'key': 'L6|45.45|-75.5',
#    'latitude': '45.45',
#    'longitude': '-75.5',
#    'propertyId': ''},
#   {'count': 8,
#    'key': 'L6|45.45|-76.7',
#    'latitude': '45.45',
#    'longitude': '-76.7',
#    'propertyId': ''},
#   {'count': 39,
#    'key': 'L6|45.5|-75.7',
#    'latitude': '45.5',
#    'longitude': '-75.7',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.5|-76',
#    'latitude': '45.5',
#    'longitude': '-76',
#    'propertyId': ''},
#   {'count': 4,
#    'key': 'L6|45.5|-76.05',
#    'latitude': '45.5',
#    'longitude': '-76.05',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.55|-74.65',
#    'latitude': '45.55',
#    'longitude': '-74.65',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.55|-75',
#    'latitude': '45.55',
#    'longitude': '-75',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45.55|-76.55',
#    'latitude': '45.55',
#    'longitude': '-76.55',
#    'propertyId': ''},
#   {'count': 33,
#    'key': 'L6|45.6|-74.6',
#    'latitude': '45.6',
#    'longitude': '-74.6',
#    'propertyId': ''},
#   {'count': 8,
#    'key': 'L6|45.6|-75.45',
#    'latitude': '45.6',
#    'longitude': '-75.45',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.65|-74.7',
#    'latitude': '45.65',
#    'longitude': '-74.7',
#    'propertyId': ''},
#   {'count': 5,
#    'key': 'L6|45.65|-74.75',
#    'latitude': '45.65',
#    'longitude': '-74.75',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.7|-74.9',
#    'latitude': '45.7',
#    'longitude': '-74.9',
#    'propertyId': ''},
#   {'count': 17,
#    'key': 'L6|45.7|-75.7',
#    'latitude': '45.7',
#    'longitude': '-75.7',
#    'propertyId': ''},
#   {'count': 2,
#    'key': 'L6|45.7|-76.85',
#    'latitude': '45.7',
#    'longitude': '-76.85',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.7|-76.9',
#    'latitude': '45.7',
#    'longitude': '-76.9',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.7|-77.05',
#    'latitude': '45.7',
#    'longitude': '-77.05',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.75|-75.5',
#    'latitude': '45.75',
#    'longitude': '-75.5',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|45.75|-76.75',
#    'latitude': '45.75',
#    'longitude': '-76.75',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|45|-76.9',
#    'latitude': '45',
#    'longitude': '-76.9',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.8|-76.45',
#    'latitude': '44.8',
#    'longitude': '-76.45',
#    'propertyId': ''},
#   {'count': 1,
#    'key': 'L6|44.85|-75.5',
#    'latitude': '44.85',
#    'longitude': '-75.5',
#    'propertyId': ''},
#   {'count': 3,
#    'key': 'L6|44.9|-75.55',
#    'latitude': '44.9',
#    'longitude': '-75.55',
#    'propertyId': ''},
# ...
#        'PermitShowAddress': True},
#       'Emails': [{'ContactId': '447642492'}],
#       'HasEmail': True,
#       'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637733982080000000/lowres/1155085.jpg',
#       'Name': 'RE/MAX AFFILIATES REALTY LTD.',
#       'OrganizationID': 91145,
#       'OrganizationType': 'Firm',
#       'PermitFreetextEmail': True,
#       'PermitShowListingLink': True,
#       'Phones': [{'AreaCode': '613',
#         'PhoneNumber': '216-1755',
#         'PhoneType': 'Telephone',
#         'PhoneTypeId': '1'},
#        {'AreaCode': '613',
#         'PhoneNumber': '825-0878',
#         'PhoneType': 'Fax',
#         'PhoneTypeId': '4'}],
#       'PhotoLastupdate': '2021-11-25 12:50:08 AM',
#       'RelativeDetailsURL': '/office/firm/91145/remax-affiliates-realty-ltd-2912-woodroffe-avenue-ottawa-ontario-k2j4p7',
#       'Websites': [{'Website': 'http://www.remaxaffiliates.ca',
#         'WebsiteTypeId': '1'}]},
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '852-5262',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'}],
#      'Photo': 'https://cdn.realtor.ca/individual/TS637708395000000000/lowres/1299506.jpg',
#      'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637708395000000000/highres/1299506.jpg',
#      'Position': 'Salesperson',
#      'RankMyAgentKey': '',
#      'RealSatisfiedKey': '',
#      'RelativeDetailsURL': '/agent/2019542/harpreet-pandher-2912-woodroffe-avenue-ottawa-ontario-k2j4p7',
#      'Websites': [{'Website': 'http://www.HomesWithHarpreet.com',
#        'WebsiteTypeId': '1'},
#       {'Website': 'http://www.facebook.com/HomesWithHarpreet',
#        'WebsiteTypeId': '2'}]}],
#    'InsertedDateUTC': '637734162088370000',
#    'Land': {'AccessType': 'Highway access',
#     'SizeFrontage': '32 ft ,10 in',
#     'SizeTotal': '32.87 ft X 109.78 ft (Irregular Lot)'},
#    'Media': [{'Description': 'VideoTourWebsite',
#      'MediaCategoryId': '2',
#      'MediaCategoryURL': 'https://youtu.be/yL8HxyL6zPs',
#      'Order': 5}],
#    'MlsNumber': '1271822',
#    'PhotoChangeDateUTC': '2021-11-25 5:50:08 AM',
#    'PostalCode': 'K2K3M8',
#    'Property': {'Address': {'AddressText': "73 SHIRLEY'S BROOK DRIVE|Kanata, Ontario K2K3M8",
#      'DisseminationArea': None,
#      'Latitude': '45.35604',
#      'Longitude': '-75.92298',
#      'PermitShowAddress': True},
#     'AmmenitiesNearBy': 'Golf Nearby, Public Transit, Shopping',
#     'ConvertedPrice': '$749,999 ',
#     'OwnershipType': 'Freehold',
#     'OwnershipTypeGroupIds': [1],
#     'Parking': [{'Name': 'Attached Garage'}, {'Name': 'Inside Entry'}],
#     'ParkingSpaceTotal': '4',
#     'ParkingType': 'Attached Garage, Inside Entry',
#     'Photo': [{'HighResPath': 'https://cdn.realtor.ca/listings/TS637733982088430000/reb76/highres/2/1271822_1.jpg',
#       'LastUpdated': '2021-11-25 12:50:08 AM',
#       'LowResPath': 'https://cdn.realtor.ca/listings/TS637733982088430000/reb76/lowres/2/1271822_1.jpg',
#       'MedResPath': 'https://cdn.realtor.ca/listings/TS637733982088430000/reb76/medres/2/1271822_1.jpg',
#       'SequenceId': '1'}],
#     'Price': '$749,999',
#     'PriceUnformattedValue': '749999',
#     'Type': 'Single Family',
#     'TypeId': '300'},
#    'PublicRemarks': 'Wonderful opportunity to live in freshly updated and move in ready 3+1 bedroom detached home with double car garage, in the heart of high-tech area of Kanata! Lots of upgrades including new hardwood flooring on the upper level, brand new carpet in the staircase, freshly painted, pot lights and a fully finished basement. The main level features spacious Living/Dining room with hardwood floors throughout, eat in kitchen with ample cupboard space which overlooks the family room with cozy gas fireplace, lots of windows and convenient main floor laundry. Upstairs you will find spacious master bedroom with walk in closet and en-suite bathroom, 2 other large bedrooms and full main bathroom with hardwood flooring throughout. The recently updated lower-level features large rec room, additional bedroom and bathroom.Fully Fenced backyard.Located close to everything your family needs: transit, schools, parks, grocery, shopping,Costco, highway and so much more! This home is perfect for your family! (25124872)',
#    'RelativeDetailsURL': '/real-estate/23853050/73-shirleys-brook-drive-kanata-shirleys-brook',
#    'RelativeURLEn': '/real-estate/23853050/73-shirleys-brook-drive-kanata-shirleys-brook',
#    'RelativeURLFr': '/immobilier/23853050/73-shirleys-brook-drive-kanata',
#    'StatusId': '1',
#    'TimeOnRealtor': '8 hours ago'},
#   {'AlternateURL': {'VideoLink': 'https://youtu.be/p6zMgFvjdKo'},
#    'Building': {'BathroomTotal': '3',
#     'Bedrooms': '4 + 2',
#     'StoriesTotal': '2',
#     'Type': 'House'},
#    'Business': {},
#    'Distance': '',
#    'HasNewImageUpdate': True,
#    'Id': '23852922',
#    'Individual': [{'AgentPhotoLastUpdated': '2021-10-26 10:04:00',
#      'CccMember': True,
#      'CorporationDisplayTypeId': '0',
#      'Emails': [{'ContactId': '453460049'}],
#      'FirstName': 'Steve',
#      'IndividualID': 1402964,
#      'LastName': 'Brouse',
#      'Name': 'Steve Brouse',
#      'Organization': {'Address': {'AddressText': '1090 AMBLESIDE DRIVE|OTTAWA, Ontario K2B8G7',
#        'DisseminationArea': None,
#        'PermitShowAddress': True},
#       'Emails': [{'ContactId': '466428711'}],
#       'HasEmail': True,
#       'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637733886230000000/lowres/49771.jpg',
#       'Name': 'COLDWELL BANKER SARAZEN REALTY',
#       'OrganizationID': 49771,
#       'OrganizationType': 'Firm',
#       'PermitFreetextEmail': True,
#       'PermitShowListingLink': True,
#       'Phones': [{'AreaCode': '613',
#         'PhoneNumber': '596-4133',
#         'PhoneType': 'Telephone',
#         'PhoneTypeId': '1'},
#        {'AreaCode': '613',
#         'PhoneNumber': '596-5905',
#         'PhoneType': 'Fax',
#         'PhoneTypeId': '4'}],
#       'PhotoLastupdate': '2021-11-24 10:10:23 PM',
#       'RelativeDetailsURL': '/office/firm/49771/coldwell-banker-sarazen-realty-1090-ambleside-drive-ottawa-ontario-k2b8g7',
#       'Websites': [{'Website': 'http://www.coldwellbankersarazen.com',
#         'WebsiteTypeId': '1'}]},
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '850-6522',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'}],
#      'Photo': 'https://cdn.realtor.ca/individual/TS637708394400000000/lowres/1067329.jpg',
#      'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637708394400000000/highres/1067329.jpg',
#      'Position': 'Salesperson',
#      'RankMyAgentKey': '',
#      'RealSatisfiedKey': '',
#      'RelativeDetailsURL': '/agent/1402964/steve-brouse-1090-ambleside-drive-ottawa-ontario-k2b8g7',
#      'Websites': [{'Website': 'http://www.investmentpropertiesottawa.com',
#        'WebsiteTypeId': '1'}]},
#     {'CorporationDisplayTypeId': '0',
#      'Emails': [{'ContactId': '462788049'}],
#      'FirstName': 'Georgia',
#      'IndividualID': 2007283,
#      'LastName': 'Carrol',
#      'Name': 'Georgia Carrol',
#      'Organization': {'Address': {'AddressText': '1090 AMBLESIDE DRIVE|OTTAWA, Ontario K2B8G7',
#        'DisseminationArea': None,
#        'PermitShowAddress': True},
#       'Emails': [{'ContactId': '466428711'}],
#       'HasEmail': True,
#       'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637733886230000000/lowres/49771.jpg',
#       'Name': 'COLDWELL BANKER SARAZEN REALTY',
#       'OrganizationID': 49771,
#       'OrganizationType': 'Firm',
#       'PermitFreetextEmail': True,
#       'PermitShowListingLink': True,
#       'Phones': [{'AreaCode': '613',
#         'PhoneNumber': '596-4133',
#         'PhoneType': 'Telephone',
#         'PhoneTypeId': '1'},
#        {'AreaCode': '613',
#         'PhoneNumber': '596-5905',
#         'PhoneType': 'Fax',
#         'PhoneTypeId': '4'}],
#       'PhotoLastupdate': '2021-11-24 10:10:23 PM',
#       'RelativeDetailsURL': '/office/firm/49771/coldwell-banker-sarazen-realty-1090-ambleside-drive-ottawa-ontario-k2b8g7',
#       'Websites': [{'Website': 'http://www.coldwellbankersarazen.com',
#         'WebsiteTypeId': '1'}]},
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '808-8235',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'}],
#      'Position': 'Salesperson',
#      'RankMyAgentKey': '',
#      'RealSatisfiedKey': '',
#      'RelativeDetailsURL': '/agent/2007283/georgia-carrol-1090-ambleside-drive-ottawa-ontario-k2b8g7',
#      'Websites': [{'Website': 'http://Georgiacarrol.ca',
#        'WebsiteTypeId': '1'}]}],
#    'InsertedDateUTC': '637734066238830000',
#    'Land': {'SizeFrontage': '50 ft', 'SizeTotal': '50 ft X 100 ft'},
#    'Media': [{'Description': 'VideoTourWebsite',
#      'MediaCategoryId': '2',
#      'MediaCategoryURL': 'https://youtu.be/p6zMgFvjdKo',
#      'Order': 5}],
#    'MlsNumber': '1271738',
#    'PhotoChangeDateUTC': '2021-11-25 3:10:23 AM',
#    'PostalCode': 'K1Y0P6',
#    'Property': {'Address': {'AddressText': '71 CLARENDON AVENUE|Ottawa, Ontario K1Y0P6',
#      'DisseminationArea': None,
#      'Latitude': '45.395621',
#      'Longitude': '-75.735068',
#      'PermitShowAddress': True},
#     'AmmenitiesNearBy': 'Public Transit, Recreation Nearby, Shopping',
#     'ConvertedPrice': '$1,675,000 ',
#     'OwnershipType': 'Freehold',
#     'OwnershipTypeGroupIds': [1],
#     'Parking': [{'Name': 'Detached Garage'}],
#     'ParkingSpaceTotal': '6',
#     'ParkingType': 'Detached Garage',
#     'Photo': [{'HighResPath': 'https://cdn.realtor.ca/listings/TS637733886238900000/reb76/highres/8/1271738_1.jpg',
#       'LastUpdated': '2021-11-24 10:10:23 PM',
#       'LowResPath': 'https://cdn.realtor.ca/listings/TS637733886238900000/reb76/lowres/8/1271738_1.jpg',
#       'MedResPath': 'https://cdn.realtor.ca/listings/TS637733886238900000/reb76/medres/8/1271738_1.jpg',
#       'SequenceId': '1'}],
#     'Price': '$1,675,000',
#     'PriceUnformattedValue': '1675000',
#     'Type': 'Single Family',
#     'TypeId': '300'},
#    'PublicRemarks': 'Welcome to 71 Clarendon Avenue, your expansive brick property on a HUGE corner lot, situated in an incredible neighbourhood;Island Park. Currently being used as a Triplex featuring,3-two bedroom units on each floor. Detached double garage with full private laneway. Space for potential further development.  Each floor comes fully equipped with 2 bedrooms, large living room, dining room, full bathroom and kitchen. Notice the hardwood flooring throughout, sun rooms and aesthetic exposed brick walls. Bright, large windows add to the ambience. Hardwood flooring in the halls and character filled wood railing leads to each  floor. Front and side porches with a balcony off of the top floor. A truly magnificent property in a desirable neighbourhood, close to all amenities, shopping, restaurants, schools and highway access. Opportunity to owner occupy with various options for use. New Roof (November 2021) 24 hour irrevocable on all offers as per form 244. 24 hour notice for showings (25124660)',
#    'RelativeDetailsURL': '/real-estate/23852922/71-clarendon-avenue-ottawa-island-park',
#    'RelativeURLEn': '/real-estate/23852922/71-clarendon-avenue-ottawa-island-park',
#    'RelativeURLFr': '/immobilier/23852922/71-clarendon-avenue-ottawa',
#    'StatusId': '1',
#    'TimeOnRealtor': '11 hours ago'},
#   {'AlternateURL': {'DetailsLink': 'https://passerelle.centris.ca/redirect.aspx?CodeDest=REMAX&NoMLS=27408361&Lang=E'},
#    'Building': {'BathroomTotal': '3',
#     'Bedrooms': '5',
#     'SizeExterior': '1402 sqft',
#     'SizeInterior': '1810 sqft',
#     'StoriesTotal': '2',
#     'Type': 'House'},
#    'Business': {},
#    'Distance': '',
#    'HasNewImageUpdate': True,
#    'Id': '23852929',
#    'Individual': [{'AgentPhotoLastUpdated': '2021-10-25 16:13:00',
#      'CorporationDisplayTypeId': '1',
#      'CorporationName': 'KARL SAUMUR COURTIER IMMOBILIER INC.',
#      'Emails': [{'ContactId': '478266145'}],
#      'FirstName': 'Karl',
#      'IndividualID': 2046513,
#      'LastName': 'Saumur',
#      'Name': 'Karl Saumur',
#      'Organization': {'Address': {'AddressText': "216 ch. d'Aylmer |Gatineau, Quebec J9H1A4",
#        'DisseminationArea': None,
#        'PermitShowAddress': True},
#       'Designation': 'Real Estate Agency',
#       'Emails': [{'ContactId': '463977626'}],
#       'HasEmail': True,
#       'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637733887340000000/lowres/1008396.jpg',
#       'Name': 'RE/MAX DIRECT INC.',
#       'OrganizationID': 57109,
#       'OrganizationType': 'Firm',
#       'PermitFreetextEmail': True,
#       'PermitShowListingLink': True,
#       'Phones': [{'AreaCode': '819',
#         'PhoneNumber': '684-0000',
#         'PhoneType': 'Telephone',
#         'PhoneTypeId': '1'},
#        {'AreaCode': '819',
#         'PhoneNumber': '685-0580',
#         'PhoneType': 'Fax',
#         'PhoneTypeId': '4'}],
#       'PhotoLastupdate': '2021-11-24 10:12:14 PM',
#       'RelativeDetailsURL': '/office/firm/57109/remax-direct-inc-216-ch-daylmer-gatineau-quebec-j9h1a4',
#       'Websites': [{'Website': 'http://remax-direct.com/',
#         'WebsiteTypeId': '1'}]},
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '819',
#        'PhoneNumber': '968-2556',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '819',
#        'PhoneNumber': '243-3370',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'Photo': 'https://cdn.realtor.ca/individual/TS637707751800000000/lowres/1322180.jpg',
#      'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637707751800000000/highres/1322180.jpg',
#      'Position': 'Residential Real Estate Broker',
#      'RankMyAgentKey': '',
#      'RealSatisfiedKey': '',
#      'RelativeDetailsURL': '/agent/2046513/karl-saumur-216-ch-daylmer--gatineau-quebec-j9h1a4',
#      'Websites': [{'Website': 'http://www.saumur.ca', 'WebsiteTypeId': '1'}]}],
#    'InsertedDateUTC': '637734067347100000',
#    'Land': {'SizeFrontage': '18.29 m', 'SizeTotal': '557.4 m2'},
#    'Media': [{'Description': 'AlternateFeatureSheetWebsite',
#      'MediaCategoryId': '1',
#      'MediaCategoryURL': 'https://passerelle.centris.ca/redirect.aspx?CodeDest=REMAX&NoMLS=27408361&Lang=E',
#      'Order': 1}],
#    'MlsNumber': '27408361',
#    'PhotoChangeDateUTC': '2021-11-25 3:12:19 AM',
#    'PostalCode': 'J9H2P6',
#    'Property': {'Address': {'AddressText': '76 Rue Bagot|Gatineau (Aylmer), Quebec J9H2P6',
#      'DisseminationArea': None,
#      'Latitude': '45.402469',
#      'Longitude': '-75.848692',
#      'PermitShowAddress': True},
#     'AmmenitiesNearBy': 'Highway, CEGEP, Golf Course, Hospital, Park, Schools, Ski hill, Public Transit, University',
#     'ConvertedPrice': '$474,900 ',
#     'FarmType': 'Other',
#     'Parking': [{'Name': 'Other'}],
#     'ParkingSpaceTotal': '2',
#     'ParkingType': 'Other',
#     'Photo': [{'Description': 'Frontage',
#       'HighResPath': 'https://cdn.realtor.ca/listings/TS637733887394700000/reb109/highres/1/27408361_1.jpg',
#       'LastUpdated': '2021-11-24 10:12:19 PM',
#       'LowResPath': 'https://cdn.realtor.ca/listings/TS637733887394700000/reb109/lowres/1/27408361_1.jpg',
#       'MedResPath': 'https://cdn.realtor.ca/listings/TS637733887394700000/reb109/medres/1/27408361_1.jpg',
#       'SequenceId': '1'}],
#     'Price': '$474,900',
#     'PriceUnformattedValue': '474900',
#     'Type': 'Single Family',
#     'TypeId': '300',
#     'ZoningType': 'Residential'},
#    'PublicRemarks': '5-bedroom single family home in Aylmer (Gatineau). Main bedroom on its own floor, with bathroom and large walk-in. Completely furnished basement with kitchenette, bathroom, living room, office and bedroom. Metal roofing (2021) and many renovations done since 2019. Only 10 minutes from Ottawa. (51261290)',
#    'RelativeDetailsURL': '/real-estate/23852929/76-rue-bagot-gatineau-aylmer-projet-pilon',
#    'RelativeURLEn': '/real-estate/23852929/76-rue-bagot-gatineau-aylmer-projet-pilon',
#    'RelativeURLFr': '/immobilier/23852929/76-rue-bagot-gatineau-aylmer-projet-pilon',
#    'StatusId': '1',
#    'TimeOnRealtor': '11 hours ago'}]}

# %%
result_json = response.json()

# %% [markdown]
# #### Step 5 - Output Keys

# %%
result_json.keys()
# Out:
# dict_keys(['ErrorCode', 'Paging', 'Results', 'Pins', 'GroupingLevel'])

# %% [markdown]
# #### Step 6 - Find your Data
#
#   * Address
#   * Bedrooms
#   * Agent Name
#   * Area Code
#   * Phone Number
#   * Price

# %%
result_json['Results']
# Out:
# [{'AlternateURL': {'VideoLink': 'https://tours.louiseingram.ca/panel/client/tours/1935266'},
#   'Building': {'BathroomTotal': '1',
#    'Bedrooms': '1 + 2',
#    'StoriesTotal': '1',
#    'Type': 'House'},
#   'Business': {},
#   'Distance': '',
#   'HasNewImageUpdate': True,
#   'Id': '23853394',
#   'Individual': [{'AgentPhotoLastUpdated': '2021-10-26 10:05:00',
#     'CorporationDisplayTypeId': '0',
#     'Emails': [{'ContactId': '453440525'}],
#     'FirstName': 'Penny',
#     'IndividualID': 1959977,
#     'LastName': 'Beavis',
#     'Name': 'Penny Beavis',
#     'Organization': {'Address': {'AddressText': '28 CLOTHIER ST., P.O. BOX 1816|KEMPTVILLE, Ontario K0G1J0',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Emails': [{'ContactId': '409527402'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637734282380000000/lowres/49761.jpg',
#      'Name': 'COLDWELL BANKER COBURN REALTY',
#      'OrganizationID': 49761,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '258-1883',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '613',
#        'PhoneNumber': '258-9164',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-25 9:10:38 AM',
#      'RelativeDetailsURL': '/office/firm/49761/coldwell-banker-coburn-realty-28-clothier-st-po-box-1816-kemptville-ontario-k0g1j0'},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '613',
#       'PhoneNumber': '323-4118',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Photo': 'https://cdn.realtor.ca/individual/TS637708395000000000/lowres/1250253.jpg',
#     'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637708395000000000/highres/1250253.jpg',
#     'Position': 'Salesperson',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/1959977/penny-beavis-28-clothier-st-po-box-1816-kemptville-ontario-k0g1j0',
#     'Websites': [{'Website': 'http://www.pennybeavis.com',
#       'WebsiteTypeId': '1'}]}],
#   'InsertedDateUTC': '637734462381770000',
#   'Land': {'SizeFrontage': '210 ft', 'SizeTotal': '1.53 ac'},
#   'Media': [{'Description': 'VideoTourWebsite',
#     'MediaCategoryId': '2',
#     'MediaCategoryURL': 'https://tours.louiseingram.ca/panel/client/tours/1935266',
#     'Order': 5}],
#   'MlsNumber': '1271842',
#   'PhotoChangeDateUTC': '2021-11-25 2:10:38 PM',
#   'PostalCode': 'K0G1J0',
#   'Property': {'Address': {'AddressText': '1567 RIVER ROAD|Kemptville, Ontario K0G1J0',
#     'DisseminationArea': None,
#     'Latitude': '45.009317',
#     'Longitude': '-75.739638',
#     'PermitShowAddress': True},
#    'AmmenitiesNearBy': 'Shopping, Water Nearby',
#    'ConvertedPrice': '$529,000 ',
#    'OwnershipType': 'Freehold',
#    'OwnershipTypeGroupIds': [1],
#    'Parking': [{'Name': 'Attached Garage'}],
#    'ParkingSpaceTotal': '15',
#    'ParkingType': 'Attached Garage',
#    'Photo': [{'HighResPath': 'https://cdn.realtor.ca/listings/TS637734282381800000/reb76/highres/2/1271842_1.jpg',
#      'LastUpdated': '2021-11-25 9:10:38 AM',
#      'LowResPath': 'https://cdn.realtor.ca/listings/TS637734282381800000/reb76/lowres/2/1271842_1.jpg',
#      'MedResPath': 'https://cdn.realtor.ca/listings/TS637734282381800000/reb76/medres/2/1271842_1.jpg',
#      'SequenceId': '1'}],
#    'Price': '$529,000',
#    'PriceUnformattedValue': '529000',
#    'Type': 'Single Family',
#    'TypeId': '300'},
#   'PublicRemarks': '1.5 acres on the Rideau River!  Welcome to 1567 River Road!  This bungalow features 3 bedrooms, 1 bathroom and the most beautiful views!  Watch sunsets and the osprey out fishing.  The home has a semi-circular paved driveway and single car garage.  The galley kitchen is bright and efficient with an attached eating area and big pantry.  There are three separate gathering rooms in the home - living room and family room on the main floor and recreation room on the lower level.  Cozy up to the wood stove in the family room while looking out onto the river.  The lower level features the recreation room (with three sided natural gas fireplace), two bedrooms, office, laundry room and large storage area. The office can be used for many purposes and could be made into an additional washroom.  The home is close to Kemptville with all its amenities.  Offers to be presented Wednesday, December 1, 2021 at 1:00 p.m.  Sellers reserve the right to review & may accept pre-emptive offers. (25125236)',
#   'RelativeDetailsURL': '/real-estate/23853394/1567-river-road-kemptville-kemptville',
#   'RelativeURLEn': '/real-estate/23853394/1567-river-road-kemptville-kemptville',
#   'RelativeURLFr': '/immobilier/23853394/1567-river-road-kemptville',
#   'StatusId': '1',
#   'TimeOnRealtor': '19 min ago'},
#  {'AlternateURL': {'VideoLink': 'https://youtu.be/vc9mYqS01ew'},
#   'Building': {'BathroomTotal': '3',
#    'Bedrooms': '3 + 0',
#    'StoriesTotal': '2',
#    'Type': 'House'},
#   'Business': {},
#   'Distance': '',
#   'HasNewImageUpdate': True,
#   'HasOpenHouseUpdate': True,
#   'Id': '23853399',
#   'Individual': [{'AgentPhotoLastUpdated': '2021-10-26 10:04:00',
#     'CorporationDisplayTypeId': '0',
#     'Emails': [{'ContactId': '453442296'}],
#     'FirstName': 'Kim',
#     'IndividualID': 1910446,
#     'LastName': 'Vo',
#     'Name': 'Kim Vo',
#     'Organization': {'Address': {'AddressText': '555 LEGGET DRIVE|KANATA, Ontario K2K2X3',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Emails': [{'ContactId': '477428300'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637734282430000000/lowres/default/royallepage.gif',
#      'Name': 'ROYAL LEPAGE TEAM REALTY',
#      'OrganizationID': 49860,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '270-8200',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '613',
#        'PhoneNumber': '270-0463',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-25 9:10:43 AM',
#      'RelativeDetailsURL': '/office/firm/49860/royal-lepage-team-realty-555-legget-drive-kanata-ontario-k2k2x3',
#      'Websites': [{'Website': 'http://www.teamrealty.ca',
#        'WebsiteTypeId': '1'}]},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '613',
#       'PhoneNumber': '255-2128',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Photo': 'https://cdn.realtor.ca/individual/TS637708394400000000/lowres/1222454.jpg',
#     'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637708394400000000/highres/1222454.jpg',
#     'Position': 'Salesperson',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/1910446/kim-vo-555-legget-drive-kanata-ontario-k2k2x3'}],
#   'InsertedDateUTC': '637734462434200000',
#   'Land': {'AccessType': 'Highway access',
#    'SizeFrontage': '30 ft',
#    'SizeTotal': '30.02 ft X 91.86 ft'},
#   'ListingBoundary': 'America/Toronto',
#   'ListingGMT': '-05:00:00',
#   'ListingTimeZone': 'Eastern Standard Time',
#   'Media': [{'Description': 'VideoTourWebsite',
#     'MediaCategoryId': '2',
#     'MediaCategoryURL': 'https://youtu.be/vc9mYqS01ew',
#     'Order': 5}],
#   'MlsNumber': '1271780',
#   'OpenHouse': [{'EndDateTime': '28/11/2021 3:00:00 PM',
#     'EventTypeID': '1',
#     'FormattedDateTime': 'Nov 28/21 - 1:00 PM To 3:00 PM',
#     'StartDateTime': '28/11/2021 1:00:00 PM',
#     'StartTime': 'Nov 28/21 - 1:00 PM To 3:00 PM'}],
#   'OpenHouseInsertDateUTC': '2021-11-25 2:15:13 PM',
#   'PhotoChangeDateUTC': '2021-11-25 2:10:43 PM',
#   'PostalCode': 'K2S0Z9',
#   'Property': {'Address': {'AddressText': '707 SAMANTHA EASTOP AVENUE|Stittsville, Ontario K2S0Z9',
#     'DisseminationArea': None,
#     'Latitude': '45.272221',
#     'Longitude': '-75.939745',
#     'PermitShowAddress': True},
#    'AmmenitiesNearBy': 'Public Transit, Recreation Nearby, Shopping',
#    'ConvertedPrice': '$666,000 ',
#    'OwnershipType': 'Freehold',
#    'OwnershipTypeGroupIds': [1],
#    'Parking': [{'Name': 'Attached Garage'}, {'Name': 'Inside Entry'}],
#    'ParkingSpaceTotal': '3',
#    'ParkingType': 'Attached Garage, Inside Entry',
#    'Photo': [{'HighResPath': 'https://cdn.realtor.ca/listings/TS637734282434270000/reb76/highres/0/1271780_1.jpg',
#      'LastUpdated': '2021-11-25 9:10:43 AM',
#      'LowResPath': 'https://cdn.realtor.ca/listings/TS637734282434270000/reb76/lowres/0/1271780_1.jpg',
#      'MedResPath': 'https://cdn.realtor.ca/listings/TS637734282434270000/reb76/medres/0/1271780_1.jpg',
#      'SequenceId': '1'}],
#    'Price': '$666,000',
#    'PriceUnformattedValue': '666000',
#    'Type': 'Single Family',
#    'TypeId': '300'},
#   'PublicRemarks': "Welcome to 707 Samantha Eastop Avenue! This detach 3bed, 2.5bath Bellevue A model by Minto features bright, open concept living space on the main level -- kitchen features beautiful quartz countertop (2021) and S/S appliances; upgraded engineered hardwood (2021); large closet and split-level powder room. Second floor features master bedroom with large 5pc ensuite and walk-in closet; two additional good sized bedrooms and 4pc full bath. Neutral paint tone throughout. Conveniently located in family-oriented neighbourhood in newer development of Potter's Key -- close to shopping, recreational facilities, schools, parks, restaurants, quick access to 417. Basement awaiting your creative touch! Move-in ready!! ***No conveyance of any written signed Offer(s) prior to December 1st, 2021 as per Form 244. (25125179)",
#   'RelativeDetailsURL': '/real-estate/23853399/707-samantha-eastop-avenue-stittsville-potters-key',
#   'RelativeURLEn': '/real-estate/23853399/707-samantha-eastop-avenue-stittsville-potters-key',
#   'RelativeURLFr': '/immobilier/23853399/707-samantha-eastop-avenue-stittsville',
#   'StatusId': '1',
#   'TimeOnRealtor': '19 min ago'},
#  {'AlternateURL': {'PhotoLink': 'http://www.8james.com',
#    'VideoLink': 'https://youtu.be/9yAPsq-Ukak'},
#   'Building': {'BathroomTotal': '1',
#    'Bedrooms': '3 + 0',
#    'StoriesTotal': '1',
#    'Type': 'House'},
#   'Business': {},
#   'Distance': '',
#   'HasNewImageUpdate': True,
#   'Id': '23853402',
#   'Individual': [{'AgentPhotoLastUpdated': '2021-09-07 14:02:00',
#     'CorporationDisplayTypeId': '0',
#     'Emails': [{'ContactId': '474581046'}],
#     'FirstName': 'Leo',
#     'IndividualID': 1994377,
#     'LastName': 'Alvarenga',
#     'Name': 'Leo Alvarenga',
#     'Organization': {'Address': {'AddressText': '610 BRONSON AVENUE|OTTAWA, Ontario K1S4E6',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Emails': [{'ContactId': '413701522'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637734282520000000/lowres/default/remaxoa.gif',
#      'Name': 'RE/MAX HALLMARK REALTY GROUP',
#      'OrganizationID': 278197,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '236-5959',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '613',
#        'PhoneNumber': '236-1515',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-25 9:10:52 AM',
#      'RelativeDetailsURL': '/office/firm/278197/remax-hallmark-realty-group-610-bronson-avenue-ottawa-ontario-k1s4e6',
#      'Websites': [{'Website': 'http://www.hallmarkottawa.com',
#        'WebsiteTypeId': '1'}]},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '613',
#       'PhoneNumber': '262-8988',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Photo': 'https://cdn.realtor.ca/individual/TS637666201200000000/lowres/1277395.jpg',
#     'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637666201200000000/highres/1277395.jpg',
#     'Position': 'Broker',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/1994377/leo-alvarenga-610-bronson-avenue-ottawa-ontario-k1s4e6',
#     'Websites': [{'Website': 'http://www.realestating.co',
#       'WebsiteTypeId': '1'}]},
#    {'AgentPhotoLastUpdated': '2021-09-07 14:04:00',
#     'CccMember': True,
#     'CorporationDisplayTypeId': '0',
#     'DesignationCodes': 'ABR ASA MCNE SRS',
#     'Emails': [{'ContactId': '477941370'}],
#     'FirstName': 'Jenniffer',
#     'IndividualID': 1941207,
#     'LastName': 'Alvarenga',
#     'Name': 'Jenniffer Alvarenga',
#     'Organization': {'Address': {'AddressText': '610 BRONSON AVENUE|OTTAWA, Ontario K1S4E6',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Emails': [{'ContactId': '413701522'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637734282520000000/lowres/default/remaxoa.gif',
#      'Name': 'RE/MAX HALLMARK REALTY GROUP',
#      'OrganizationID': 278197,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '236-5959',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '613',
#        'PhoneNumber': '236-1515',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-25 9:10:52 AM',
#      'RelativeDetailsURL': '/office/firm/278197/remax-hallmark-realty-group-610-bronson-avenue-ottawa-ontario-k1s4e6',
#      'Websites': [{'Website': 'http://www.hallmarkottawa.com',
#        'WebsiteTypeId': '1'}]},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '613',
#       'PhoneNumber': '218-3543',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Photo': 'https://cdn.realtor.ca/individual/TS637666202400000000/lowres/1238489.jpg',
#     'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637666202400000000/highres/1238489.jpg',
#     'Position': 'Broker',
#     'RankMyAgentKey': '22346',
#     'RealSatisfiedKey': 'Jen-Alvarenga',
#     'RelativeDetailsURL': '/agent/1941207/jenniffer-alvarenga-610-bronson-avenue-ottawa-ontario-k1s4e6',
#     'Websites': [{'Website': 'http://www.lifestylehomesottawa.com',
#       'WebsiteTypeId': '1'},
#      {'Website': 'https://www.facebook.com/RealEstating.Co',
#       'WebsiteTypeId': '2'},
#      {'Website': 'http://www.jenniffer.ca', 'WebsiteTypeId': '3'}]}],
#   'InsertedDateUTC': '637734462520130000',
#   'Land': {'LandscapeFeatures': 'Landscaped',
#    'SizeFrontage': '66 ft',
#    'SizeTotal': '66 ft X 132 ft'},
#   'Media': [{'Description': 'VideoTourWebsite',
#     'MediaCategoryId': '2',
#     'MediaCategoryURL': 'https://youtu.be/9yAPsq-Ukak',
#     'Order': 5},
#    {'Description': 'AdditionalPicturesWebsite',
#     'MediaCategoryId': '5',
#     'MediaCategoryURL': 'http://www.8james.com',
#     'Order': 2}],
#   'MlsNumber': '1271262',
#   'PhotoChangeDateUTC': '2021-11-25 2:10:52 PM',
#   'PostalCode': 'K0A1A0',
#   'Property': {'Address': {'AddressText': '8 ST JAMES STREET|Almonte, Ontario K0A1A0',
#     'DisseminationArea': None,
#     'Latitude': '45.232797',
#     'Longitude': '-76.188078',
#     'PermitShowAddress': True},
#    'AmmenitiesNearBy': 'Golf Nearby, Recreation Nearby, Shopping, Water Nearby',
#    'ConvertedPrice': '$399,900 ',
#    'OwnershipType': 'Freehold',
#    'OwnershipTypeGroupIds': [1],
#    'Parking': [{'Name': 'Attached Garage'}, {'Name': 'Surfaced'}],
#    'ParkingSpaceTotal': '3',
#    'ParkingType': 'Attached Garage, Surfaced',
#    'Photo': [{'HighResPath': 'https://cdn.realtor.ca/listings/TS637734282520200000/reb76/highres/2/1271262_1.jpg',
#      'LastUpdated': '2021-11-25 9:10:52 AM',
#      'LowResPath': 'https://cdn.realtor.ca/listings/TS637734282520200000/reb76/lowres/2/1271262_1.jpg',
#      'MedResPath': 'https://cdn.realtor.ca/listings/TS637734282520200000/reb76/medres/2/1271262_1.jpg',
#      'SequenceId': '1'}],
#    'Price': '$399,900',
#    'PriceUnformattedValue': '399900',
#    'Type': 'Single Family',
#    'TypeId': '300'},
#   'PublicRemarks': 'Welcome to 8 St James St., located in Almonte\x97a picturesque town just outside Ottawa, known as \x93the friendly town\x94 & a popular filming spot for movies. This cozy 3 bdrm detached bungalow sits on a massive corner lot and is perfect for first time buyers, investors, or anyone looking for a change from the busy city. The home\x92s practical layout features a bright eat-in kitchen w/ lots of cabinet space, generously-sized bedrooms, and a spacious single attached garage that doubles as a workshop. A screened-in sunroom, accessed through the home office, overlooks the huge fenced-in yard. The entire home welcomes tons of natural light, and w/ many updates (roof & tankless hot water 2014, windows 2016, furnace 2017),it\x92s move-in ready! Close to the Mississippi river, shopping, recreation, schools, & the hospital, this home has everything you need! Book a showing today! Offers to be presented November 30 at 2:00pm.However, the Seller reserves the right to review and entertain pre-emptive offers. (25124664)',
#   'RelativeDetailsURL': '/real-estate/23853402/8-st-james-street-almonte-almonte',
#   'RelativeURLEn': '/real-estate/23853402/8-st-james-street-almonte-almonte',
#   'RelativeURLFr': '/immobilier/23853402/8-st-james-street-almonte',
#   'StatusId': '1',
#   'TimeOnRealtor': '19 min ago'},
#  {'AlternateURL': {'VideoLink': 'http://www.212donbrown.com'},
#   'Building': {'BathroomTotal': '3',
#    'Bedrooms': '3 + 0',
#    'StoriesTotal': '2',
#    'Type': 'Row / Townhouse'},
#   'Business': {},
#   'Distance': '',
#   'HasNewImageUpdate': True,
#   'Id': '23853404',
#   'Individual': [{'AgentPhotoLastUpdated': '2021-10-26 10:04:00',
#     'CorporationDisplayTypeId': '0',
#     'Emails': [{'ContactId': '467945448'}],
#     'FirstName': 'Paul',
#     'IndividualID': 1404285,
#     'LastName': 'Rushforth',
#     'Name': 'Paul Rushforth',
#     'Organization': {'Address': {'AddressText': '3002 ST. JOSEPH BLVD.|OTTAWA, Ontario K1E1E2',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Name': 'PAUL RUSHFORTH REAL ESTATE INC.',
#      'OrganizationID': 261424,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '590-9393',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '613',
#        'PhoneNumber': '590-1313',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-25 9:10:56 AM',
#      'RelativeDetailsURL': '/office/firm/261424/paul-rushforth-real-estate-inc-3002-st-joseph-blvd-ottawa-ontario-k1e1e2'},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '613',
#       'PhoneNumber': '788-2122',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Photo': 'https://cdn.realtor.ca/individual/TS637708394400000000/lowres/1121451.jpg',
#     'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637708394400000000/highres/1121451.jpg',
#     'Position': 'Broker of Record',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/1404285/paul-rushforth-3002-st-joseph-blvd-ottawa-ontario-k1e1e2',
#     'Websites': [{'Website': 'http://www.paulrushforth.com',
#       'WebsiteTypeId': '1'}]},
#    {'CorporationDisplayTypeId': '0',
#     'Emails': [{'ContactId': '453439921'}],
#     'FirstName': 'James',
#     'IndividualID': 1971444,
#     'LastName': 'Daly',
#     'Name': 'James Daly',
#     'Organization': {'Address': {'AddressText': '100 DIDSBURY ROAD SUITE 2|OTTAWA, Ontario K2T0C2',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Name': 'PAUL RUSHFORTH REAL ESTATE INC.',
#      'OrganizationID': 275303,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '271-2800',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '613',
#        'PhoneNumber': '271-2801',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-25 9:10:56 AM',
#      'RelativeDetailsURL': '/office/firm/275303/paul-rushforth-real-estate-inc-100-didsbury-road-suite-2-ottawa-ontario-k2t0c2'},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '613',
#       'PhoneNumber': '762-9062',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Position': 'Salesperson',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/1971444/james-daly-100-didsbury-road-suite-2-ottawa-ontario-k2t0c2',
#     'Websites': [{'Website': 'http://www.paulrushforth.com',
#       'WebsiteTypeId': '1'}]}],
#   'InsertedDateUTC': '637734462566070000',
#   'Land': {'SizeFrontage': '29 ft ,6 in', 'SizeTotal': '29.53 ft X 87.17 ft'},
#   'Media': [{'Description': 'VideoTourWebsite',
#     'MediaCategoryId': '2',
#     'MediaCategoryURL': 'http://www.212donbrown.com',
#     'Order': 5}],
#   'MlsNumber': '1271096',
#   'PhotoChangeDateUTC': '2021-11-25 2:10:56 PM',
#   'PostalCode': 'K2M0M6',
#   'Property': {'Address': {'AddressText': '212 DON BROWN PRIVATE|Ottawa, Ontario K2M0M6',
#     'DisseminationArea': None,
#     'Latitude': '45.270781',
#     'Longitude': '-75.857464',
#     'PermitShowAddress': True},
#    'ConvertedPrice': '$649,900 ',
#    'OwnershipType': 'Freehold',
#    'OwnershipTypeGroupIds': [1],
#    'Parking': [{'Name': 'Attached Garage'}],
#    'ParkingSpaceTotal': '4',
#    'ParkingType': 'Attached Garage',
#    'Photo': [{'HighResPath': 'https://cdn.realtor.ca/listings/TS637734282566130000/reb76/highres/6/1271096_1.jpg',
#      'LastUpdated': '2021-11-25 9:10:56 AM',
#      'LowResPath': 'https://cdn.realtor.ca/listings/TS637734282566130000/reb76/lowres/6/1271096_1.jpg',
#      'MedResPath': 'https://cdn.realtor.ca/listings/TS637734282566130000/reb76/medres/6/1271096_1.jpg',
#      'SequenceId': '1'}],
#    'Price': '$649,900',
#    'PriceUnformattedValue': '649900',
#    'Type': 'Single Family',
#    'TypeId': '300'},
#   'PublicRemarks': 'Offers welcome any time on this absolutely stunning end unit townhome, with a 2 car garage! Main level features hardwood flooring throughout, bright and beautiful kitchen with open concept living room/dining room and plenty of windows allowing loads of natural light. Second level features a huge primary bedroom with a walk in closet, a fantastic full bath ensuite, and two more generous sized bedrooms with another full bath. Fully finished lower level including a family room, large windows, rough in for a bathroom and plenty of storage. This one is a must see! Monthly fee for snow removal and maintenance of common areas. 24 hr irrevocable on all offers. (25124500)',
#   'RelativeDetailsURL': '/real-estate/23853404/212-don-brown-private-ottawa-monahan-landing',
#   'RelativeURLEn': '/real-estate/23853404/212-don-brown-private-ottawa-monahan-landing',
#   'RelativeURLFr': '/immobilier/23853404/212-don-brown-private-ottawa',
#   'StatusId': '1',
#   'TimeOnRealtor': '19 min ago'},
#  {'AlternateURL': {'DetailsLink': 'https://passerelle.centris.ca/redirect.aspx?CodeDest=VENDIRECT&NoMLS=13448362&Lang=E'},
#   'Building': {'BathroomTotal': '2',
#    'Bedrooms': '4',
#    'SizeExterior': '672 sqft',
#    'SizeInterior': '1300 sqft',
#    'StoriesTotal': '2',
#    'Type': 'House'},
#   'Business': {},
#   'Distance': '',
#   'HasNewImageUpdate': True,
#   'Id': '23853382',
#   'Individual': [{'AgentPhotoLastUpdated': '2021-03-24 13:20:00',
#     'CorporationDisplayTypeId': '0',
#     'Emails': [{'ContactId': '413046508'}],
#     'FirstName': 'Pascal',
#     'IndividualID': 1951856,
#     'LastName': 'Langevin',
#     'Name': 'Pascal Langevin',
#     'Organization': {'Address': {'AddressText': '5-3055 boul. St-Martin Ouest |Laval, Quebec H7T0J3',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Designation': 'Real Estate Agency',
#      'Emails': [{'ContactId': '463986854'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637734279920000000/lowres/1221184.jpg',
#      'Name': 'VENDIRECT INC.',
#      'OrganizationID': 261177,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '855',
#        'PhoneNumber': '262-3131',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '514',
#        'PhoneNumber': '262-3131',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-25 9:06:32 AM',
#      'RelativeDetailsURL': '/office/firm/261177/vendirect-inc-5-3055-boul-st-martin-ouest-laval-quebec-h7t0j3',
#      'Websites': [{'Website': 'http://vendirect.ca', 'WebsiteTypeId': '1'}]},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '819',
#       'PhoneNumber': '743-7744',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'},
#      {'AreaCode': '514',
#       'PhoneNumber': '666-2131',
#       'PhoneType': 'Fax',
#       'PhoneTypeId': '4'}],
#     'Photo': 'https://cdn.realtor.ca/individual/TS637521888000000000/lowres/1246244.jpg',
#     'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637521888000000000/highres/1246244.jpg',
#     'Position': 'Real Estate Broker',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/1951856/pascal-langevin-5-3055-boul-st-martin-ouest--laval-quebec-h7t0j3',
#     'Websites': [{'Website': 'http://vendirect.ca', 'WebsiteTypeId': '1'}]}],
#   'InsertedDateUTC': '637734459927870000',
#   'Land': {'SizeFrontage': '32 ft ,1 in', 'SizeTotal': '3982.65 sqft'},
#   'Media': [{'Description': 'AlternateFeatureSheetWebsite',
#     'MediaCategoryId': '1',
#     'MediaCategoryURL': 'https://passerelle.centris.ca/redirect.aspx?CodeDest=VENDIRECT&NoMLS=13448362&Lang=E',
#     'Order': 1}],
#   'MlsNumber': '13448362',
#   'PhotoChangeDateUTC': '2021-11-25 2:15:26 PM',
#   'PostalCode': 'J8M1X2',
#   'Property': {'Address': {'AddressText': '164 Rue du Châtelet|Gatineau (Masson-Angers), Quebec J8M1X2',
#     'DisseminationArea': None,
#     'Latitude': '45.529774',
#     'Longitude': '-75.481687',
#     'PermitShowAddress': True},
#    'AmmenitiesNearBy': 'Highway, Hospital, Park, Schools, Public Transit',
#    'ConvertedPrice': '$259,900 ',
#    'FarmType': 'Other',
#    'Parking': [{'Name': 'Other'}],
#    'ParkingSpaceTotal': '4',
#    'ParkingType': 'Other',
#    'Photo': [{'Description': 'Frontage',
#      'HighResPath': 'https://cdn.realtor.ca/listings/TS637734285259400000/reb5/highres/2/13448362_1.jpg',
#      'LastUpdated': '2021-11-25 9:15:25 AM',
#      'LowResPath': 'https://cdn.realtor.ca/listings/TS637734285259400000/reb5/lowres/2/13448362_1.jpg',
#      'MedResPath': 'https://cdn.realtor.ca/listings/TS637734285259400000/reb5/medres/2/13448362_1.jpg',
#      'SequenceId': '1'}],
#    'Price': '$259,900',
#    'PriceUnformattedValue': '259900',
#    'Type': 'Single Family',
#    'TypeId': '300',
#    'ZoningType': 'Residential'},
#   'PublicRemarks': "Superbe jumelé situé dans un secteur recherché, près de tous les services et transport en commun. 4 chambre, 2 salles de bains complètes dont une au ssol luxueuse (2021) + salle d'eau au rdc. Grandes pièces bien divisées. S-sol aménagé. Grande cour aménagée avec terrasse et piscine ovale 2020 avec chauffe-eau et remise. (37301744)",
#   'RelativeDetailsURL': '/real-estate/23853382/164-rue-du-châtelet-gatineau-masson-angers-angers',
#   'RelativeURLEn': '/real-estate/23853382/164-rue-du-châtelet-gatineau-masson-angers-angers',
#   'RelativeURLFr': '/immobilier/23853382/164-rue-du-châtelet-gatineau-masson-angers-angers',
#   'StatusId': '1',
#   'TimeOnRealtor': '23 min ago'},
#  {'AlternateURL': {'PhotoLink': 'http://richardchartier.point2homes.biz/Listing/VirtualTour.ashx?ListingID=482087088',
#    'VideoLink': 'http://richardchartier.point2homes.biz/Listing/VirtualTour.ashx?ListingID=482087088'},
#   'Building': {'BathroomTotal': '3',
#    'Bedrooms': '2 + 1',
#    'StoriesTotal': '1',
#    'Type': 'House'},
#   'Business': {},
#   'Distance': '',
#   'HasNewImageUpdate': True,
#   'Id': '23853397',
#   'Individual': [{'AgentPhotoLastUpdated': '2021-10-26 10:04:00',
#     'CorporationDisplayTypeId': '0',
#     'Emails': [{'ContactId': '461124371'}],
#     'FirstName': 'Richard',
#     'IndividualID': 1403046,
#     'LastName': 'Chartier',
#     'Name': 'Richard Chartier',
#     'Organization': {'Address': {'AddressText': '1749 WOODWARD DRIVE|OTTAWA, Ontario K2C0P9',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Emails': [{'ContactId': '422769381'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637734282410000000/lowres/1004055.jpg',
#      'Name': 'COLDWELL BANKER FIRST OTTAWA REALTY',
#      'OrganizationID': 49762,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '728-2664',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '613',
#        'PhoneNumber': '728-0548',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-25 9:10:41 AM',
#      'RelativeDetailsURL': '/office/firm/49762/coldwell-banker-first-ottawa-realty-1749-woodward-drive-ottawa-ontario-k2c0p9'},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '613',
#       'PhoneNumber': '878-5111',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Photo': 'https://cdn.realtor.ca/individual/TS637708394400000000/lowres/1067243.jpg',
#     'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637708394400000000/highres/1067243.jpg',
#     'Position': 'Salesperson',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/1403046/richard-chartier-1749-woodward-drive-ottawa-ontario-k2c0p9',
#     'Websites': [{'Website': 'http://www.richardchartier.com',
#       'WebsiteTypeId': '1'},
#      {'Website': 'http://www.facebook.com/richard.chartier.92',
#       'WebsiteTypeId': '2'},
#      {'Website': 'http://www.linkedin.com/in/richard-chartier-cd-abr-57a25b10',
#       'WebsiteTypeId': '3'}]}],
#   'InsertedDateUTC': '637734462411500000',
#   'Land': {'AccessType': 'Highway access',
#    'LandscapeFeatures': 'Landscaped, Underground sprinkler',
#    'SizeFrontage': '44 ft ,2 in',
#    'SizeTotal': '44.13 ft X 104.99 ft'},
#   'Media': [{'Description': 'VideoTourWebsite',
#     'MediaCategoryId': '2',
#     'MediaCategoryURL': 'http://richardchartier.point2homes.biz/Listing/VirtualTour.ashx?ListingID=482087088',
#     'Order': 5},
#    {'Description': 'AdditionalPicturesWebsite',
#     'MediaCategoryId': '5',
#     'MediaCategoryURL': 'http://richardchartier.point2homes.biz/Listing/VirtualTour.ashx?ListingID=482087088',
#     'Order': 2}],
#   'MlsNumber': '1271795',
#   'PhotoChangeDateUTC': '2021-11-25 2:10:41 PM',
#   'PostalCode': 'K4A5E1',
#   'Property': {'Address': {'AddressText': '204 JANET WAY|Orleans, Ontario K4A5E1',
#     'DisseminationArea': None,
#     'Latitude': '45.466279',
#     'Longitude': '-75.462076',
#     'PermitShowAddress': True},
#    'AmmenitiesNearBy': 'Public Transit, Recreation Nearby, Shopping',
#    'ConvertedPrice': '$889,900 ',
#    'OwnershipType': 'Freehold',
#    'OwnershipTypeGroupIds': [1],
#    'Parking': [{'Name': 'Attached Garage'},
#     {'Name': 'Inside Entry'},
#     {'Name': 'Surfaced'}],
#    'ParkingSpaceTotal': '6',
#    'ParkingType': 'Attached Garage, Inside Entry, Surfaced',
#    'Photo': [{'Description': 'Stunning 2+1  bedroom & 3 full bathroom bungalow.',
#      'HighResPath': 'https://cdn.realtor.ca/listings/TS637734282411570000/reb76/highres/5/1271795_1.jpg',
#      'LastUpdated': '2021-11-25 9:10:41 AM',
#      'LowResPath': 'https://cdn.realtor.ca/listings/TS637734282411570000/reb76/lowres/5/1271795_1.jpg',
#      'MedResPath': 'https://cdn.realtor.ca/listings/TS637734282411570000/reb76/medres/5/1271795_1.jpg',
#      'SequenceId': '1'}],
#    'Price': '$889,900',
#    'PriceUnformattedValue': '889900',
#    'Type': 'Single Family',
#    'TypeId': '300'},
#   'PublicRemarks': 'EXTREME PRIDE OF OWNERSHIP! Over $150K spent in quality upgrades over the years. Gorgeous 2 + 1 bedrm & 3 full bathrm bungalow w/vaulted ceiling & skylight. Upgraded to Energy Star package w/hi-eff furnace, HRV, Low E-argon PVC windows & more. Enlarged kitchen w/more cabinets, pantry, granite counter-top, undermount sink, volcano glass mesh backsplash, SS appliances. Hwd flooring throughout main level incl stairs w/wrought iron spindles to bsmt. Primary bedrm w/walk-in closet & 5 piece luxury ensuite bathrm. Impressive basement w/quality flooring, beautiful wet bar w/fridge & cabinets, large bedrm, beautiful bathrm & plenty of storage space. Interlock walkway & flower bed to large covered front veranda w/PVC railing. Front lawn irrigation system, maintenance free backyard w/entertainment size interlock patio, new beautiful composite fence & artificial turf. Offers to be presented at 6pm on 01 December 2021, however Seller reserve the right to review & may accept pre-emptive offers. (25125192)',
#   'RelativeDetailsURL': '/real-estate/23853397/204-janet-way-orleans-notting-hillsummerside',
#   'RelativeURLEn': '/real-estate/23853397/204-janet-way-orleans-notting-hillsummerside',
#   'RelativeURLFr': '/immobilier/23853397/204-janet-way-orleans',
#   'StatusId': '1',
#   'TimeOnRealtor': '19 min ago'},
#  {'AlternateURL': {'PhotoLink': 'https://fulltone360.hd.pics/892-Bideford-St',
#    'VideoLink': 'https://www.youtube.com/embed/E5s2gs_5x6A'},
#   'Building': {'BathroomTotal': '2',
#    'Bedrooms': '3 + 0',
#    'StoriesTotal': '2',
#    'Type': 'House'},
#   'Business': {},
#   'Distance': '',
#   'HasNewImageUpdate': True,
#   'Id': '23853398',
#   'Individual': [{'CorporationDisplayTypeId': '0',
#     'Emails': [{'ContactId': '465923864'}],
#     'FirstName': 'Lee-Anne',
#     'IndividualID': 1993462,
#     'LastName': 'Gordon',
#     'Name': 'Lee-Anne Gordon',
#     'Organization': {'Address': {'AddressText': '100 ARGYLE AVENUE, SUITE 102|OTTAWA, Ontario K2P1B6',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Emails': [{'ContactId': '409527589'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637734282420000000/lowres/1004060.jpg',
#      'Name': 'COLDWELL BANKER RHODES & COMPANY',
#      'OrganizationID': 49769,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '236-9551',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '613',
#        'PhoneNumber': '236-2692',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-25 9:10:42 AM',
#      'RelativeDetailsURL': '/office/firm/49769/coldwell-banker-rhodes-company-100-argyle-avenue-suite-102-ottawa-ontario-k2p1b6'},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '613',
#       'PhoneNumber': '816-7034',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Position': 'Salesperson',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/1993462/lee-anne-gordon-100-argyle-avenue-suite-102-ottawa-ontario-k2p1b6',
#     'Websites': [{'Website': 'http://www.beyondthedeal.ca',
#       'WebsiteTypeId': '1'}]}],
#   'InsertedDateUTC': '637734462422600000',
#   'Land': {'SizeFrontage': '34 ft ,6 in', 'SizeTotal': '34.51 ft X 119.75 ft'},
#   'Media': [{'Description': 'VideoTourWebsite',
#     'MediaCategoryId': '2',
#     'MediaCategoryURL': 'https://www.youtube.com/embed/E5s2gs_5x6A',
#     'Order': 5},
#    {'Description': 'AdditionalPicturesWebsite',
#     'MediaCategoryId': '5',
#     'MediaCategoryURL': 'https://fulltone360.hd.pics/892-Bideford-St',
#     'Order': 2}],
#   'MlsNumber': '1271794',
#   'PhotoChangeDateUTC': '2021-11-25 2:10:42 PM',
#   'PostalCode': 'K4A2C4',
#   'Property': {'Address': {'AddressText': '892 BIDEFORD STREET|Ottawa, Ontario K4A2C4',
#     'DisseminationArea': None,
#     'Latitude': '45.479932',
#     'Longitude': '-75.477434',
#     'PermitShowAddress': True},
#    'AmmenitiesNearBy': 'Public Transit, Recreation Nearby, Shopping',
#    'ConvertedPrice': '$569,900 ',
#    'OwnershipType': 'Freehold',
#    'OwnershipTypeGroupIds': [1],
#    'Parking': [{'Name': 'Attached Garage'}],
#    'ParkingSpaceTotal': '3',
#    'ParkingType': 'Attached Garage',
#    'Photo': [{'HighResPath': 'https://cdn.realtor.ca/listings/TS637734282422670000/reb76/highres/4/1271794_1.jpg',
#      'LastUpdated': '2021-11-25 9:10:42 AM',
#      'LowResPath': 'https://cdn.realtor.ca/listings/TS637734282422670000/reb76/lowres/4/1271794_1.jpg',
#      'MedResPath': 'https://cdn.realtor.ca/listings/TS637734282422670000/reb76/medres/4/1271794_1.jpg',
#      'SequenceId': '1'}],
#    'Price': '$569,900',
#    'PriceUnformattedValue': '569900',
#    'Type': 'Single Family',
#    'TypeId': '300'},
#   'PublicRemarks': 'This 3 bed, 2 bath home is conveniently located on a quiet street within walking distance to parks, schools, shopping and restaurants and has been meticulously maintained and beautifully updated by its original owners. The main floor is flooded with natural light and features a large foyer, newly refinished hardwood floors, a gorgeous updated kitchen with SS appliances and granite countertops, an open concept living/dining room with wood burning fireplace, and flat ceilings with pot lights. Patio doors lead you to a deck/gazebo and your massive fenced yard! The second level features a generous primary bedroom, a stunning cheater ensuite with double sinks and 2 secondary bedrooms. The lower level awaits your personal touches and includes a bathroom rough-in. Roof (2009), Furnace/AC (approx 2010), Owned HWT (2016), Windows (PVC w/transferable warranty). Offers presented Wed, Dec 1st at 6:30PM, however Sellers reserve right to review and accept pre-emptive offers subject to conditions. (25125192)',
#   'RelativeDetailsURL': '/real-estate/23853398/892-bideford-street-ottawa-fallingbrook',
#   'RelativeURLEn': '/real-estate/23853398/892-bideford-street-ottawa-fallingbrook',
#   'RelativeURLFr': '/immobilier/23853398/892-bideford-street-ottawa',
#   'StatusId': '1',
#   'TimeOnRealtor': '19 min ago'},
#  {'AlternateURL': {'VideoLink': 'https://myvisuallistings.com/vt/320064'},
#   'Building': {'Ammenities': 'Laundry - In Suite',
#    'BathroomTotal': '3',
#    'Bedrooms': '3 + 0',
#    'StoriesTotal': '2',
#    'Type': 'House'},
#   'Business': {},
#   'Distance': '',
#   'HasNewImageUpdate': True,
#   'Id': '23853403',
#   'Individual': [{'AgentPhotoLastUpdated': '2017-07-06 16:19:00',
#     'CorporationDisplayTypeId': '0',
#     'Emails': [{'ContactId': '457044185'}],
#     'FirstName': 'Constance',
#     'IndividualID': 1659468,
#     'LastName': 'McCrea',
#     'Name': 'Constance McCrea',
#     'Organization': {'Address': {'AddressText': '1723 CARLING AVENUE, SUITE 1|OTTAWA, Ontario K2A1C8',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Emails': [{'ContactId': '477425117'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637734282530000000/lowres/default/royallepage.gif',
#      'Name': 'ROYAL LEPAGE TEAM REALTY',
#      'OrganizationID': 49866,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '725-1171',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '613',
#        'PhoneNumber': '725-3323',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-25 9:10:53 AM',
#      'RelativeDetailsURL': '/office/firm/49866/royal-lepage-team-realty-1723-carling-avenue-suite-1-ottawa-ontario-k2a1c8',
#      'Websites': [{'Website': 'http://www.teamrealty.ca',
#        'WebsiteTypeId': '1'}]},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '613',
#       'PhoneNumber': '291-4112',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Photo': 'https://cdn.realtor.ca/individual/TS636349547400000000/lowres/1167494.jpg',
#     'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS636349547400000000/highres/1167494.jpg',
#     'Position': 'Broker',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/1659468/constance-mccrea-1723-carling-avenue-suite-1-ottawa-ontario-k2a1c8',
#     'Websites': [{'Website': 'http://www.ConstanceMcCrea.com',
#       'WebsiteTypeId': '1'},
#      {'Website': 'http://Facebook.com/constance.mccrea', 'WebsiteTypeId': '2'},
#      {'Website': 'http://www.linkedin.com/in/constancemccrea',
#       'WebsiteTypeId': '3'},
#      {'Website': 'http://twitter.com/constancemc', 'WebsiteTypeId': '4'}]}],
#   'InsertedDateUTC': '637734462531100000',
#   'Land': {'AccessType': 'Highway access', 'LandscapeFeatures': 'Landscaped'},
#   'Media': [{'Description': 'VideoTourWebsite',
#     'MediaCategoryId': '2',
#     'MediaCategoryURL': 'https://myvisuallistings.com/vt/320064',
#     'Order': 5}],
#   'MlsNumber': '1271238',
#   'PhotoChangeDateUTC': '2021-11-25 2:10:53 PM',
#   'PostalCode': 'K1C0A5',
#   'Property': {'Address': {'AddressText': '266 TITANIUM PRIVATE UNIT#B|Ottawa, Ontario K1C0A5',
#     'DisseminationArea': None,
#     'Latitude': '45.481345',
#     'Longitude': '-75.52718',
#     'PermitShowAddress': True},
#    'AmmenitiesNearBy': 'Public Transit, Recreation Nearby, Shopping, Water Nearby',
#    'ConvertedPrice': '$439,900 ',
#    'OwnershipType': 'Condominium/Strata',
#    'OwnershipTypeGroupIds': [2],
#    'Parking': [{'Name': 'Underground'}, {'Name': 'Visitor Parking'}],
#    'ParkingSpaceTotal': '1',
#    'ParkingType': 'Underground, Visitor Parking',
#    'Photo': [{'Description': 'Welcome to Quarry Glen 266 B Titanium Private. Step into style in this contemporary design! Rarely available, this 3 bedroom, 2.5 bath condo is sure to delight.',
#      'HighResPath': 'https://cdn.realtor.ca/listings/TS637734282531170000/reb76/highres/8/1271238_1.jpg',
#      'LastUpdated': '2021-11-25 9:10:53 AM',
#      'LowResPath': 'https://cdn.realtor.ca/listings/TS637734282531170000/reb76/lowres/8/1271238_1.jpg',
#      'MedResPath': 'https://cdn.realtor.ca/listings/TS637734282531170000/reb76/medres/8/1271238_1.jpg',
#      'SequenceId': '1'}],
#    'Price': '$439,900',
#    'PriceUnformattedValue': '439900',
#    'Type': 'Single Family',
#    'TypeId': '300'},
#   'PublicRemarks': "Step into Style in this Contemporary Design! This 3 bedroom 2.5 bath end unit is sure to please. The view of the rock faced Quarry is spectacular. Light fills the space with windows on two sides. Well designed kitchen includes stainless appliances, the main level features the living/dining area, kitchen with island, storage room, 2 piece powder room. Ascend the stairs to the 3 bedrooms + laundry. Large primary bedroom with ensuite bath, full 4 piece bath and 2 additional bedrooms. The flooring is luxury, washed oak, waterproof vinyl plank installed in Oct 2021. Most of the home was painted in 2021. Move-in ready. Includes one underground heated parking space. Enjoy many happy years in this pet friendly complex that's within walking distance to public transit, Place D'Orleans shopping mall. schools, parks, bike/walking trails, and Petrie Island Beach. Offers reviewed December 1, 2021 by 4pm. 24 Hr. Irrevocable, Seller reserves the right to review pre-emptive offers. Buy a Best Seller! (25124641)",
#   'RelativeDetailsURL': '/real-estate/23853403/266-titanium-private-unitb-ottawa-quarry-glenconvent-glen-north',
#   'RelativeURLEn': '/real-estate/23853403/266-titanium-private-unitb-ottawa-quarry-glenconvent-glen-north',
#   'RelativeURLFr': '/immobilier/23853403/266-titanium-private-unitb-ottawa',
#   'StatusId': '1',
#   'TimeOnRealtor': '19 min ago'},
#  {'AlternateURL': {'DetailsLink': 'https://passerelle.centris.ca/redirect.aspx?CodeDest=REMAX&NoMLS=14326049&Lang=E'},
#   'Building': {'BathroomTotal': '1',
#    'Bedrooms': '1',
#    'SizeExterior': '47.1 m2',
#    'SizeInterior': '49.5 m2',
#    'StoriesTotal': '10',
#    'Type': 'Apartment'},
#   'Business': {},
#   'Distance': '',
#   'HasNewImageUpdate': True,
#   'Id': '23853349',
#   'Individual': [{'AgentPhotoLastUpdated': '2021-03-05 08:25:00',
#     'CorporationDisplayTypeId': '0',
#     'Emails': [{'ContactId': '464650843'}],
#     'FirstName': 'Lucie',
#     'IndividualID': 1461495,
#     'LastName': 'Dussault',
#     'Name': 'Lucie Dussault',
#     'Organization': {'Address': {'AddressText': '10 - 2310 rue St-Louis |Gatineau, Quebec J8T5L7',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Designation': 'Real Estate Agency',
#      'Emails': [{'ContactId': '463977567'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637734253790000000/lowres/1267034.jpg',
#      'Name': 'RE/MAX DIRECT INC. - Gatineau',
#      'OrganizationID': 275638,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '819',
#        'PhoneNumber': '770-2100',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '819',
#        'PhoneNumber': '205-9886',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-25 8:22:59 AM',
#      'RelativeDetailsURL': '/office/firm/275638/remax-direct-inc-gatineau-10-2310-rue-st-louis-gatineau-quebec-j8t5l7',
#      'Websites': [{'Website': 'http://remax-direct.com/',
#        'WebsiteTypeId': '1'}]},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '819',
#       'PhoneNumber': '328-3211',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Photo': 'https://cdn.realtor.ca/individual/TS637505295000000000/lowres/1081900.jpg',
#     'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637505295000000000/highres/1081900.jpg',
#     'Position': 'Real Estate Broker',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/1461495/lucie-dussault-10---2310-rue-st-louis--gatineau-quebec-j8t5l7'},
#    {'AgentPhotoLastUpdated': '2020-06-22 12:14:00',
#     'CorporationDisplayTypeId': '0',
#     'Emails': [{'ContactId': '452196374'}],
#     'FirstName': 'Sylvie',
#     'IndividualID': 1969405,
#     'LastName': 'Charbonneau',
#     'Name': 'Sylvie Charbonneau',
#     'Organization': {'Address': {'AddressText': '10 - 2310 rue St-Louis |Gatineau, Quebec J8T5L7',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Designation': 'Real Estate Agency',
#      'Emails': [{'ContactId': '463977567'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637734253790000000/lowres/1267034.jpg',
#      'Name': 'RE/MAX DIRECT INC. - Gatineau',
#      'OrganizationID': 275638,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '819',
#        'PhoneNumber': '770-2100',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '819',
#        'PhoneNumber': '205-9886',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-25 8:22:59 AM',
#      'RelativeDetailsURL': '/office/firm/275638/remax-direct-inc-gatineau-10-2310-rue-st-louis-gatineau-quebec-j8t5l7',
#      'Websites': [{'Website': 'http://remax-direct.com/',
#        'WebsiteTypeId': '1'}]},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '819',
#       'PhoneNumber': '208-2970',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Photo': 'https://cdn.realtor.ca/individual/TS637284248400000000/lowres/1256888.jpg',
#     'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637284248400000000/highres/1256888.jpg',
#     'Position': 'Residential Real Estate Broker',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/1969405/sylvie-charbonneau-10---2310-rue-st-louis--gatineau-quebec-j8t5l7'}],
#   'InsertedDateUTC': '637734433793070000',
#   'Land': {},
#   'Media': [{'Description': 'AlternateFeatureSheetWebsite',
#     'MediaCategoryId': '1',
# ...
#     'Emails': [{'ContactId': '453435077'}],
#     'FirstName': 'Harpreet',
#     'IndividualID': 2019542,
#     'LastName': 'Pandher',
#     'Name': 'Harpreet Pandher',
#     'Organization': {'Address': {'AddressText': '2912 WOODROFFE AVENUE|OTTAWA, Ontario K2J4P7',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Emails': [{'ContactId': '447642492'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637733982080000000/lowres/1155085.jpg',
#      'Name': 'RE/MAX AFFILIATES REALTY LTD.',
#      'OrganizationID': 91145,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '216-1755',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '613',
#        'PhoneNumber': '825-0878',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-25 12:50:08 AM',
#      'RelativeDetailsURL': '/office/firm/91145/remax-affiliates-realty-ltd-2912-woodroffe-avenue-ottawa-ontario-k2j4p7',
#      'Websites': [{'Website': 'http://www.remaxaffiliates.ca',
#        'WebsiteTypeId': '1'}]},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '613',
#       'PhoneNumber': '852-5262',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Photo': 'https://cdn.realtor.ca/individual/TS637708395000000000/lowres/1299506.jpg',
#     'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637708395000000000/highres/1299506.jpg',
#     'Position': 'Salesperson',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/2019542/harpreet-pandher-2912-woodroffe-avenue-ottawa-ontario-k2j4p7',
#     'Websites': [{'Website': 'http://www.HomesWithHarpreet.com',
#       'WebsiteTypeId': '1'},
#      {'Website': 'http://www.facebook.com/HomesWithHarpreet',
#       'WebsiteTypeId': '2'}]}],
#   'InsertedDateUTC': '637734162088370000',
#   'Land': {'AccessType': 'Highway access',
#    'SizeFrontage': '32 ft ,10 in',
#    'SizeTotal': '32.87 ft X 109.78 ft (Irregular Lot)'},
#   'Media': [{'Description': 'VideoTourWebsite',
#     'MediaCategoryId': '2',
#     'MediaCategoryURL': 'https://youtu.be/yL8HxyL6zPs',
#     'Order': 5}],
#   'MlsNumber': '1271822',
#   'PhotoChangeDateUTC': '2021-11-25 5:50:08 AM',
#   'PostalCode': 'K2K3M8',
#   'Property': {'Address': {'AddressText': "73 SHIRLEY'S BROOK DRIVE|Kanata, Ontario K2K3M8",
#     'DisseminationArea': None,
#     'Latitude': '45.35604',
#     'Longitude': '-75.92298',
#     'PermitShowAddress': True},
#    'AmmenitiesNearBy': 'Golf Nearby, Public Transit, Shopping',
#    'ConvertedPrice': '$749,999 ',
#    'OwnershipType': 'Freehold',
#    'OwnershipTypeGroupIds': [1],
#    'Parking': [{'Name': 'Attached Garage'}, {'Name': 'Inside Entry'}],
#    'ParkingSpaceTotal': '4',
#    'ParkingType': 'Attached Garage, Inside Entry',
#    'Photo': [{'HighResPath': 'https://cdn.realtor.ca/listings/TS637733982088430000/reb76/highres/2/1271822_1.jpg',
#      'LastUpdated': '2021-11-25 12:50:08 AM',
#      'LowResPath': 'https://cdn.realtor.ca/listings/TS637733982088430000/reb76/lowres/2/1271822_1.jpg',
#      'MedResPath': 'https://cdn.realtor.ca/listings/TS637733982088430000/reb76/medres/2/1271822_1.jpg',
#      'SequenceId': '1'}],
#    'Price': '$749,999',
#    'PriceUnformattedValue': '749999',
#    'Type': 'Single Family',
#    'TypeId': '300'},
#   'PublicRemarks': 'Wonderful opportunity to live in freshly updated and move in ready 3+1 bedroom detached home with double car garage, in the heart of high-tech area of Kanata! Lots of upgrades including new hardwood flooring on the upper level, brand new carpet in the staircase, freshly painted, pot lights and a fully finished basement. The main level features spacious Living/Dining room with hardwood floors throughout, eat in kitchen with ample cupboard space which overlooks the family room with cozy gas fireplace, lots of windows and convenient main floor laundry. Upstairs you will find spacious master bedroom with walk in closet and en-suite bathroom, 2 other large bedrooms and full main bathroom with hardwood flooring throughout. The recently updated lower-level features large rec room, additional bedroom and bathroom.Fully Fenced backyard.Located close to everything your family needs: transit, schools, parks, grocery, shopping,Costco, highway and so much more! This home is perfect for your family! (25124872)',
#   'RelativeDetailsURL': '/real-estate/23853050/73-shirleys-brook-drive-kanata-shirleys-brook',
#   'RelativeURLEn': '/real-estate/23853050/73-shirleys-brook-drive-kanata-shirleys-brook',
#   'RelativeURLFr': '/immobilier/23853050/73-shirleys-brook-drive-kanata',
#   'StatusId': '1',
#   'TimeOnRealtor': '8 hours ago'},
#  {'AlternateURL': {'VideoLink': 'https://youtu.be/p6zMgFvjdKo'},
#   'Building': {'BathroomTotal': '3',
#    'Bedrooms': '4 + 2',
#    'StoriesTotal': '2',
#    'Type': 'House'},
#   'Business': {},
#   'Distance': '',
#   'HasNewImageUpdate': True,
#   'Id': '23852922',
#   'Individual': [{'AgentPhotoLastUpdated': '2021-10-26 10:04:00',
#     'CccMember': True,
#     'CorporationDisplayTypeId': '0',
#     'Emails': [{'ContactId': '453460049'}],
#     'FirstName': 'Steve',
#     'IndividualID': 1402964,
#     'LastName': 'Brouse',
#     'Name': 'Steve Brouse',
#     'Organization': {'Address': {'AddressText': '1090 AMBLESIDE DRIVE|OTTAWA, Ontario K2B8G7',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Emails': [{'ContactId': '466428711'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637733886230000000/lowres/49771.jpg',
#      'Name': 'COLDWELL BANKER SARAZEN REALTY',
#      'OrganizationID': 49771,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '596-4133',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '613',
#        'PhoneNumber': '596-5905',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-24 10:10:23 PM',
#      'RelativeDetailsURL': '/office/firm/49771/coldwell-banker-sarazen-realty-1090-ambleside-drive-ottawa-ontario-k2b8g7',
#      'Websites': [{'Website': 'http://www.coldwellbankersarazen.com',
#        'WebsiteTypeId': '1'}]},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '613',
#       'PhoneNumber': '850-6522',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Photo': 'https://cdn.realtor.ca/individual/TS637708394400000000/lowres/1067329.jpg',
#     'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637708394400000000/highres/1067329.jpg',
#     'Position': 'Salesperson',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/1402964/steve-brouse-1090-ambleside-drive-ottawa-ontario-k2b8g7',
#     'Websites': [{'Website': 'http://www.investmentpropertiesottawa.com',
#       'WebsiteTypeId': '1'}]},
#    {'CorporationDisplayTypeId': '0',
#     'Emails': [{'ContactId': '462788049'}],
#     'FirstName': 'Georgia',
#     'IndividualID': 2007283,
#     'LastName': 'Carrol',
#     'Name': 'Georgia Carrol',
#     'Organization': {'Address': {'AddressText': '1090 AMBLESIDE DRIVE|OTTAWA, Ontario K2B8G7',
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Emails': [{'ContactId': '466428711'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637733886230000000/lowres/49771.jpg',
#      'Name': 'COLDWELL BANKER SARAZEN REALTY',
#      'OrganizationID': 49771,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '613',
#        'PhoneNumber': '596-4133',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '613',
#        'PhoneNumber': '596-5905',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-24 10:10:23 PM',
#      'RelativeDetailsURL': '/office/firm/49771/coldwell-banker-sarazen-realty-1090-ambleside-drive-ottawa-ontario-k2b8g7',
#      'Websites': [{'Website': 'http://www.coldwellbankersarazen.com',
#        'WebsiteTypeId': '1'}]},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '613',
#       'PhoneNumber': '808-8235',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'}],
#     'Position': 'Salesperson',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/2007283/georgia-carrol-1090-ambleside-drive-ottawa-ontario-k2b8g7',
#     'Websites': [{'Website': 'http://Georgiacarrol.ca',
#       'WebsiteTypeId': '1'}]}],
#   'InsertedDateUTC': '637734066238830000',
#   'Land': {'SizeFrontage': '50 ft', 'SizeTotal': '50 ft X 100 ft'},
#   'Media': [{'Description': 'VideoTourWebsite',
#     'MediaCategoryId': '2',
#     'MediaCategoryURL': 'https://youtu.be/p6zMgFvjdKo',
#     'Order': 5}],
#   'MlsNumber': '1271738',
#   'PhotoChangeDateUTC': '2021-11-25 3:10:23 AM',
#   'PostalCode': 'K1Y0P6',
#   'Property': {'Address': {'AddressText': '71 CLARENDON AVENUE|Ottawa, Ontario K1Y0P6',
#     'DisseminationArea': None,
#     'Latitude': '45.395621',
#     'Longitude': '-75.735068',
#     'PermitShowAddress': True},
#    'AmmenitiesNearBy': 'Public Transit, Recreation Nearby, Shopping',
#    'ConvertedPrice': '$1,675,000 ',
#    'OwnershipType': 'Freehold',
#    'OwnershipTypeGroupIds': [1],
#    'Parking': [{'Name': 'Detached Garage'}],
#    'ParkingSpaceTotal': '6',
#    'ParkingType': 'Detached Garage',
#    'Photo': [{'HighResPath': 'https://cdn.realtor.ca/listings/TS637733886238900000/reb76/highres/8/1271738_1.jpg',
#      'LastUpdated': '2021-11-24 10:10:23 PM',
#      'LowResPath': 'https://cdn.realtor.ca/listings/TS637733886238900000/reb76/lowres/8/1271738_1.jpg',
#      'MedResPath': 'https://cdn.realtor.ca/listings/TS637733886238900000/reb76/medres/8/1271738_1.jpg',
#      'SequenceId': '1'}],
#    'Price': '$1,675,000',
#    'PriceUnformattedValue': '1675000',
#    'Type': 'Single Family',
#    'TypeId': '300'},
#   'PublicRemarks': 'Welcome to 71 Clarendon Avenue, your expansive brick property on a HUGE corner lot, situated in an incredible neighbourhood;Island Park. Currently being used as a Triplex featuring,3-two bedroom units on each floor. Detached double garage with full private laneway. Space for potential further development.  Each floor comes fully equipped with 2 bedrooms, large living room, dining room, full bathroom and kitchen. Notice the hardwood flooring throughout, sun rooms and aesthetic exposed brick walls. Bright, large windows add to the ambience. Hardwood flooring in the halls and character filled wood railing leads to each  floor. Front and side porches with a balcony off of the top floor. A truly magnificent property in a desirable neighbourhood, close to all amenities, shopping, restaurants, schools and highway access. Opportunity to owner occupy with various options for use. New Roof (November 2021) 24 hour irrevocable on all offers as per form 244. 24 hour notice for showings (25124660)',
#   'RelativeDetailsURL': '/real-estate/23852922/71-clarendon-avenue-ottawa-island-park',
#   'RelativeURLEn': '/real-estate/23852922/71-clarendon-avenue-ottawa-island-park',
#   'RelativeURLFr': '/immobilier/23852922/71-clarendon-avenue-ottawa',
#   'StatusId': '1',
#   'TimeOnRealtor': '11 hours ago'},
#  {'AlternateURL': {'DetailsLink': 'https://passerelle.centris.ca/redirect.aspx?CodeDest=REMAX&NoMLS=27408361&Lang=E'},
#   'Building': {'BathroomTotal': '3',
#    'Bedrooms': '5',
#    'SizeExterior': '1402 sqft',
#    'SizeInterior': '1810 sqft',
#    'StoriesTotal': '2',
#    'Type': 'House'},
#   'Business': {},
#   'Distance': '',
#   'HasNewImageUpdate': True,
#   'Id': '23852929',
#   'Individual': [{'AgentPhotoLastUpdated': '2021-10-25 16:13:00',
#     'CorporationDisplayTypeId': '1',
#     'CorporationName': 'KARL SAUMUR COURTIER IMMOBILIER INC.',
#     'Emails': [{'ContactId': '478266145'}],
#     'FirstName': 'Karl',
#     'IndividualID': 2046513,
#     'LastName': 'Saumur',
#     'Name': 'Karl Saumur',
#     'Organization': {'Address': {'AddressText': "216 ch. d'Aylmer |Gatineau, Quebec J9H1A4",
#       'DisseminationArea': None,
#       'PermitShowAddress': True},
#      'Designation': 'Real Estate Agency',
#      'Emails': [{'ContactId': '463977626'}],
#      'HasEmail': True,
#      'Logo': 'https://cdn.realtor.ca/organization/en-CA/TS637733887340000000/lowres/1008396.jpg',
#      'Name': 'RE/MAX DIRECT INC.',
#      'OrganizationID': 57109,
#      'OrganizationType': 'Firm',
#      'PermitFreetextEmail': True,
#      'PermitShowListingLink': True,
#      'Phones': [{'AreaCode': '819',
#        'PhoneNumber': '684-0000',
#        'PhoneType': 'Telephone',
#        'PhoneTypeId': '1'},
#       {'AreaCode': '819',
#        'PhoneNumber': '685-0580',
#        'PhoneType': 'Fax',
#        'PhoneTypeId': '4'}],
#      'PhotoLastupdate': '2021-11-24 10:12:14 PM',
#      'RelativeDetailsURL': '/office/firm/57109/remax-direct-inc-216-ch-daylmer-gatineau-quebec-j9h1a4',
#      'Websites': [{'Website': 'http://remax-direct.com/',
#        'WebsiteTypeId': '1'}]},
#     'PermitFreetextEmail': True,
#     'PermitShowListingLink': True,
#     'Phones': [{'AreaCode': '819',
#       'PhoneNumber': '968-2556',
#       'PhoneType': 'Telephone',
#       'PhoneTypeId': '1'},
#      {'AreaCode': '819',
#       'PhoneNumber': '243-3370',
#       'PhoneType': 'Fax',
#       'PhoneTypeId': '4'}],
#     'Photo': 'https://cdn.realtor.ca/individual/TS637707751800000000/lowres/1322180.jpg',
#     'PhotoHighRes': 'https://cdn.realtor.ca/individual/TS637707751800000000/highres/1322180.jpg',
#     'Position': 'Residential Real Estate Broker',
#     'RankMyAgentKey': '',
#     'RealSatisfiedKey': '',
#     'RelativeDetailsURL': '/agent/2046513/karl-saumur-216-ch-daylmer--gatineau-quebec-j9h1a4',
#     'Websites': [{'Website': 'http://www.saumur.ca', 'WebsiteTypeId': '1'}]}],
#   'InsertedDateUTC': '637734067347100000',
#   'Land': {'SizeFrontage': '18.29 m', 'SizeTotal': '557.4 m2'},
#   'Media': [{'Description': 'AlternateFeatureSheetWebsite',
#     'MediaCategoryId': '1',
#     'MediaCategoryURL': 'https://passerelle.centris.ca/redirect.aspx?CodeDest=REMAX&NoMLS=27408361&Lang=E',
#     'Order': 1}],
#   'MlsNumber': '27408361',
#   'PhotoChangeDateUTC': '2021-11-25 3:12:19 AM',
#   'PostalCode': 'J9H2P6',
#   'Property': {'Address': {'AddressText': '76 Rue Bagot|Gatineau (Aylmer), Quebec J9H2P6',
#     'DisseminationArea': None,
#     'Latitude': '45.402469',
#     'Longitude': '-75.848692',
#     'PermitShowAddress': True},
#    'AmmenitiesNearBy': 'Highway, CEGEP, Golf Course, Hospital, Park, Schools, Ski hill, Public Transit, University',
#    'ConvertedPrice': '$474,900 ',
#    'FarmType': 'Other',
#    'Parking': [{'Name': 'Other'}],
#    'ParkingSpaceTotal': '2',
#    'ParkingType': 'Other',
#    'Photo': [{'Description': 'Frontage',
#      'HighResPath': 'https://cdn.realtor.ca/listings/TS637733887394700000/reb109/highres/1/27408361_1.jpg',
#      'LastUpdated': '2021-11-24 10:12:19 PM',
#      'LowResPath': 'https://cdn.realtor.ca/listings/TS637733887394700000/reb109/lowres/1/27408361_1.jpg',
#      'MedResPath': 'https://cdn.realtor.ca/listings/TS637733887394700000/reb109/medres/1/27408361_1.jpg',
#      'SequenceId': '1'}],
#    'Price': '$474,900',
#    'PriceUnformattedValue': '474900',
#    'Type': 'Single Family',
#    'TypeId': '300',
#    'ZoningType': 'Residential'},
#   'PublicRemarks': '5-bedroom single family home in Aylmer (Gatineau). Main bedroom on its own floor, with bathroom and large walk-in. Completely furnished basement with kitchenette, bathroom, living room, office and bedroom. Metal roofing (2021) and many renovations done since 2019. Only 10 minutes from Ottawa. (51261290)',
#   'RelativeDetailsURL': '/real-estate/23852929/76-rue-bagot-gatineau-aylmer-projet-pilon',
#   'RelativeURLEn': '/real-estate/23852929/76-rue-bagot-gatineau-aylmer-projet-pilon',
#   'RelativeURLFr': '/immobilier/23852929/76-rue-bagot-gatineau-aylmer-projet-pilon',
#   'StatusId': '1',
#   'TimeOnRealtor': '11 hours ago'}]

# %%
len(result_json['Results'])
# Out:
# 12

# %%
# starting point
result_items = result_json['Results']

# %%
len(result_items)
# Out:
# 12

# %%
# address
result_items[0]['Property']['Address']['AddressText']
# Out:
# '1567 RIVER ROAD|Kemptville, Ontario K0G1J0'

# %%
# bedrooms
result_items[0]['Building']['Bedrooms']
# Out:
# '1 + 2'

# %%
# bathrooms
result_items[0]['Building']['BathroomTotal']
# Out:
# '1'

# %%
# agent name
result_items[0]['Individual'][0]['Name']
# Out:
# 'Penny Beavis'

# %%
# area code
result_items[0]['Individual'][0]['Phones'][0]['AreaCode']
# Out:
# '613'

# %%
# telephone
result_items[0]['Individual'][0]['Phones'][0]['PhoneNumber']
# Out:
# '323-4118'

# %%
# price
result_items[0]['Property']['Price']
# Out:
# '$529,000'

# %% [markdown]
# #### Step 7 - Put everything together - Loop through results and append data inside a list

# %%
address = []
bedrooms = []
bathrooms = []
agent_name = []
area_code = []
phone_number = []
price = []

for result in result_items:
  # address
  try:
    address.append(result['Property']['Address']['AddressText'])
  except:
    address.append('')

  # bedrooms
  try:
    bedrooms.append(result['Building']['Bedrooms'])
  except:
    bedrooms.append('')

  # bathrooms
  try:
    bathrooms.append(result['Building']['BathroomTotal'])
  except:
    bathrooms.append('')

  # agent_name
  try:
    agent_name.append(result['Individual'][0]['Name'])
  except:
    gent_name.append('')

  # area_code
  try:
    area_code.append(result['Individual'][0]['Phones'][0]['AreaCode'])
  except:
    area_code.append('')

  # phone_number
  try:
    phone_number.append(result['Individual'][0]['Phones'][0]['PhoneNumber'])
  except:
    phone_number.append('')

  # price
  try:
    price.append(result['Property']['Price'])
  except:
    price.append('')

# %%
# Cleaner code
'''
address = []
bedrooms = []
bathrooms = []
agent_name = []
area_code = []
phone_number = []
price = []

for result in result_items:
  # address
  address.append(result.get['Property']['Address']['AddressText'], '')
  
  # bedrooms
  bedrooms.append(result.bet['Building']['Bedrooms'], '')
  
  # bathrooms
  bathrooms.append(result.get['Building']['BathroomTotal'], '')
  
  # agent_name
  agent_name.append(result.get['Individual'][0]['Name'], '')
  
  # area_code
  area_code.append(result.get['Individual'][0]['Phones'][0]['AreaCode'], '')
  
  # phone_number
  phone_number.append(result.get['Individual'][0]['Phones'][0]['PhoneNumber'], '')
  
  # price
  price.append(result.get['Property']['Price'], '')

'''
# Out:
# "\naddress = []\nbedrooms = []\nbathrooms = []\nagent_name = []\narea_code = []\nphone_number = []\nprice = []\n\nfor result in result_items:\n  # address\n  address.append(result.get['Property']['Address']['AddressText'], '')\n  \n  # bedrooms\n  bedrooms.append(result.bet['Building']['Bedrooms'], '')\n  \n  # bathrooms\n  bathrooms.append(result.get['Building']['BathroomTotal'], '')\n  \n  # agent_name\n  agent_name.append(result.get['Individual'][0]['Name'], '')\n  \n  # area_code\n  area_code.append(result.get['Individual'][0]['Phones'][0]['AreaCode'], '')\n  \n  # phone_number\n  phone_number.append(result.get['Individual'][0]['Phones'][0]['PhoneNumber'], '')\n  \n  # price\n  price.append(result.get['Property']['Price'], '')\n\n"

# %% [markdown]
# #### Step 8 - Pandas Dataframe

# %%
df_realtor = pd.DataFrame({'Address': address, 'Bedrooms': bedrooms, 'Bathrooms': bathrooms, 'Agent Name': agent_name, 'Area Code': area_code,
                           'Telephone': phone_number, 'Price': price})

# %%
df_realtor
# Out:
#                                               Address  ...       Price
# 0          1567 RIVER ROAD|Kemptville, Ontario K0G1J0  ...    $529,000
# 1   707 SAMANTHA EASTOP AVENUE|Stittsville, Ontari...  ...    $666,000
# 2           8 ST JAMES STREET|Almonte, Ontario K0A1A0  ...    $399,900
# 3        212 DON BROWN PRIVATE|Ottawa, Ontario K2M0M6  ...    $649,900
# 4   164 Rue du Châtelet|Gatineau (Masson-Angers), ...  ...    $259,900
# 5               204 JANET WAY|Orleans, Ontario K4A5E1  ...    $889,900
# 6          892 BIDEFORD STREET|Ottawa, Ontario K4A2C4  ...    $569,900
# 7   266 TITANIUM PRIVATE UNIT#B|Ottawa, Ontario K1...  ...    $439,900
# 8   23 Rue de la Soeur-Jeanne-Marie-Chavoin|#712|G...  ...    $119,900
# 9     73 SHIRLEY'S BROOK DRIVE|Kanata, Ontario K2K3M8  ...    $749,999
# 10         71 CLARENDON AVENUE|Ottawa, Ontario K1Y0P6  ...  $1,675,000
# 11      76 Rue Bagot|Gatineau (Aylmer), Quebec J9H2P6  ...    $474,900
#
# [12 rows x 7 columns]

# %% [markdown]
# #### Step 9 - Multiple Pages

# %%
address = []
bedrooms = []
bathrooms = []
agent_name = []
area_code = []
phone_number = []
price = []

for i in range(1, 51):
  headers = {
      'authority': 'api2.realtor.ca',
      'sec-ch-ua': '" Not A;Brand";v="99", "Chromium";v="96", "Google Chrome";v="96"',
      'accept': '*/*',
      'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
      'sec-ch-ua-mobile': '?0',
      'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36',
      'sec-ch-ua-platform': '"Windows"',
      'origin': 'https://www.realtor.ca',
      'sec-fetch-site': 'same-site',
      'sec-fetch-mode': 'cors',
      'sec-fetch-dest': 'empty',
      'referer': 'https://www.realtor.ca/',
      'accept-language': 'en-US,en;q=0.9,pt;q=0.8',
      'cookie': 'visid_incap_2269415=XY7Ff6FISH+XbDEMypW0DJXCl2EAAAAAQUIPAAAAAACa6q1MGoE55Eox1mrFFuhm; _fbp=fb.1.1637335707946.82525080; gig_bootstrap_3_mrQiIl6ov44s2X3j6NGWVZ9SDDtplqV7WgdcyEpGYnYxl7ygDWPQHqQqtpSiUfko=gigya-pr_ver4; visid_incap_2271082=BHCBF2JIQaK4CNJILm17xbLCl2EAAAAAQUIPAAAAAADFMVMUuqSR2qfEAAn3fPcA; incap_ses_1452_2269415=2aVeXzf2/zRcdEhDYYomFGuFn2EAAAAA0o392l8I4x+XO5eRXrvVxA==; nlbi_2269415=d9unboAgoRiiqWtgkG5lugAAAABDgwNL8voKdZLtsKHNnEco; _gid=GA1.2.957073111.1637844339; ASP.NET_SessionId=cop3nuc4yhokjdcz2necxjww; nlbi_2271082=4zL3PYDMEGXdaorXcbDG1QAAAABb1b+Q5x8yrL6GBBKtMhx3; incap_ses_1452_2271082=3jk1Vopiim+CekhDYYomFG+Fn2EAAAAAqAsJ92vLT413AjEkbVFJCw==; nlbi_2269415_2147483646=LhDvEZF1wxR0bEJakG5lugAAAADDYIUwi1cA4PI1DkP6uKGo; _ga=GA1.2.239090420.1637335707; reese84=3:JXnYiFIMw2zWLN0ngQVgJg==:...:EAUMrBqaOZKI74nTbJxdskhbAvyHlo5cy6fNWGWgAbg=; _4c_=fVNdb5swFP0rFVN5KtQYf0AlHrpUqiJlXbV2mrSXysAlsUowM05oWuW%2F7zqiybRK5QXf43M%2FfO%2B5b8G4gi64SkQqM8ZSIQSVF8Ez7Ibg6i2wuva%2FbXAVlFKUUjU8yhRJIiZEFZWiKaMka4AzKpNSkeAiePGxGE%2BSRBKZE7m%2FCKp%2BivEWbGyLoVbO9cPV5eU4jrEF1Tpj40pdrlX%2F5bcx6wVsoS3ycAadA1swHlNOUkrP6SySPJZ5nnMSLpTTblPDN%2FXiKZKnMgkXplse0UiymBMpshNXdwVjsWSUpf9wEY2kjElOKQ23Gsai1YMLH4x1hYhuwvtbMPN6KJYpeWooS8D94SFid2oNxXfn1KiwtnNKvt%2BF99b0YN3ucdfDrTWbfn5TJEf0AZStVv5uXiP8aFU3qMpp000YDWcba6GrdsXs%2Bgb7WZkasGVJHuex7697RQub7s%2FQ%2BcH0tsbz7fXTz%2FkNmjTNSU4YJbGfaZpynAPe99bUm8o9OcyDrBHKs6F%2BxosatrqCp1HXbuUToQRO6Ar0cuUQxi56tLeegqdRd7UZ%2F%2Fea0KOXyDmiC9UtN2oJk%2BvCLJdQn81RdUGj2gEQw%2F5sdVd5Clozs%2Bmc3aHx1apX3SL0AwZdox60ao2dmfUarK6UF5M93SCvtGYcwFc5W1mzhrPc12VQzMGvQ3EDmhYawCbbT6WIvEE7OGR4xycMt%2BMERwe495OgeGgNluW9cKuQDYfhntjBflqRVOYpapMJjuvmHL4kE4z4Dxlb%2Fb51VV5XDc%2FzKG0oj1B6MiqThkW8rlialSRtCA2OITMmcPkEo1NIlMkUsW%2BniMmJzDPJSMbFO5kd8%2FfbiU0%2FVCs%2BVlvD8OxMP73wE98PL93v%2FwI%3D; _ga_Y07J3B53QP=GS1.1.1637844338.2.1.1637844422.60; _dc_gtm_UA-12908513-11=1',
  }

  data = {
    'ZoomLevel': '9',
    'LatitudeMax': '45.75371',
    'LongitudeMax': '-74.50768',
    'LatitudeMin': '44.74243',
    'LongitudeMin': '-77.09222',
    'Sort': '6-D',
    'PropertyTypeGroupID': '1',
    'PropertySearchTypeId': '1',
    'TransactionTypeId': '2',
    'Currency': 'CAD',
    'RecordsPerPage': '12',
    'ApplicationId': '1',
    'CultureId': '1',
    'Version': '7.0',
    'CurrentPage': str(i),
  }

  # response
  response = requests.post('https://api2.realtor.ca/Listing.svc/PropertySearch_Post', headers=headers, data=data)

  # json object
  result_json = response.json()

  # result items
  result_items = result_json['Results']
  
  for result in result_items:
    # address
     try:
       address.append(result['Property']['Address']['AddressText'])
     except:
       address.append('')
    
     # bedrooms
     try:
       bedrooms.append(result['Building']['Bedrooms'])
     except:
       bedrooms.append('')
    
     # bathrooms
     try:
       bathrooms.append(result['Building']['BathroomTotal'])
     except:
       bathrooms.append('')
    
     # agent_name
     try:
       agent_name.append(result['Individual'][0]['Name'])
     except:
       gent_name.append('')
    
     # area_code
     try:
       area_code.append(result['Individual'][0]['Phones'][0]['AreaCode'])
     except:
       area_code.append('')
    
     # phone_number
     try:
       phone_number.append(result['Individual'][0]['Phones'][0]['PhoneNumber'])
     except:
       phone_number.append('')
    
     # price
     try:
       price.append(result['Property']['Price'])
     except:
       price.append('')

# %%
df_realtor = pd.DataFrame({'Address': address, 'Bedrooms': bedrooms, 'Bathrooms': bathrooms, 'Agent Name': agent_name, 'Area Code': area_code,
                           'Telephone': phone_number, 'Price': price})

# %%
df_realtor
# Out:
#                                                Address  ...       Price
# 0    23 Rue de la Soeur-Jeanne-Marie-Chavoin|#712|G...  ...    $119,900
# 1      73 SHIRLEY'S BROOK DRIVE|Kanata, Ontario K2K3M8  ...    $749,999
# 2           71 CLARENDON AVENUE|Ottawa, Ontario K1Y0P6  ...  $1,675,000
# 3        76 Rue Bagot|Gatineau (Aylmer), Quebec J9H2P6  ...    $474,900
# 4       105 OXFORD STREET W|Kemptville, Ontario K0G1J0  ...    $938,500
# ..                                                 ...  ...         ...
# 595       5283 DRISCOLL DRIVE|Manotick, Ontario K4M1E9  ...    $699,900
# 596         1439 SALE BARN ROAD|Greely, Ontario K4P1L6  ...  $3,000,000
# 597      1039 MULLER POINT Lane|Ardoch, Ontario K0H2J0  ...    $225,900
# 598           572 EDISON AVENUE|Ottawa, Ontario K2A1V4  ...  $1,449,000
# 599               6 RATAN COURT|Ottawa, Ontario K2S2L1  ...    $879,000
#
# [600 rows x 7 columns]

# %% [markdown]
# #### Step 10 - Store results in Excel

# %%
df_realtor.to_excel('realtor_multiple_pages.xlsx', index=False)

# %% [markdown]
# #### Step 11 - PostgreSQL

# %%
# create sqlalchemy engine
engine = sqlalchemy.create_engine('postgres://user:password@localhost:5432/database')
df_realtor.to_sql('real_state_results', engine)
